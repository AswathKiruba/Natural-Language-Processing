# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# # Introduction

# %% [markdown]
# The NLTK module is a massive tool kit, aimed at helping you with the entire Natural Language Processing (NLP) methodology. NLTK will aid you with everything from splitting sentences from paragraphs, splitting up words, recognizing the part of speech of those words, highlighting the main subjects, and then even with helping your machine to understand what the text is all about. In this series, we're going to tackle the field of opinion mining, or sentiment analysis.

# %%
import nltk
#Data imports
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

#Math
import math

#Plot
#plot import
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline

# %%
#Download all NLTK packages
#nltk.download()

# %% [markdown]
# # Tokenizing

# %% [markdown]
# Splitting sentences and words from the body of text.
# There are two types:
#
# Word Tokenizer : splits by words
#
# Sentence Tokenizer : splits by sentences
#
#  Each "entity" that is a part of whatever was split up based on rules. For examples, each word is a token when a sentence is "tokenized" into words. Each sentence can also be a token, if you tokenized the sentences out of a paragraph.

# %% [markdown]
# # Corpus

# %% [markdown]
# Body of text, singular. Corpora is the plural of this. Example: A collection of medical journals

# %% [markdown]
# # Lexicon

# %% [markdown]
#  Words and their meanings. Example: English dictionary. Consider, however, that various fields will have different lexicons. For example: To a financial investor, the first meaning for the word "Bull" is someone who is confident about the market, as compared to the common English lexicon, where the first meaning for the word "Bull" is an animal. As such, there is a special lexicon for financial investors, doctors, children, mechanics, and so on.

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
example_text = "Hello Mr. Smith, how are you doing today? The weather is good today and Python is awesome. The sky line is good."

# %%
print(sent_tokenize(example_text))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is good today and Python is awesome.', 'The sky line is good.']

# %%
print(word_tokenize(example_text))
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'good', 'today', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'line', 'is', 'good', '.']

# %%
for i in word_tokenize(example_text):
    print(i)
# Out:
# Hello
# Mr.
# Smith
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# good
# today
# and
# Python
# is
# awesome
# .
# The
# sky
# line
# is
# good
# .

# %% [markdown]
# # Stop Words

# %% [markdown]
# The words that doesn't have any meaning. They are filler words. They make meaning for our language but not for the data analysis.
#
# The idea of Natural Language Processing is to do some form of analysis, or processing, where the machine can understand, at least to some level, what the text means, says, or implies.
#
# This is an obviously massive challenge, but there are steps to doing it that anyone can follow. The main idea, however, is that computers simply do not, and will not, ever understand words directly. Humans don't either *shocker*. In humans, memory is broken down into electrical signals in the brain, in the form of neural groups that fire in patterns. There is a lot about the brain that remains unknown, but, the more we break down the human brain to the basic elements, we find out basic the elements really are. Well, it turns out computers store information in a very similar way! We need a way to get as close to that as possible if we're going to mimic how humans read and understand text. Generally, computers use numbers for everything, but we often see directly in programming where we use binary signals (True or False, which directly translate to 1 or 0, which originates directly from either the presence of an electrical signal (True, 1), or not (False, 0)). To do this, we need a way to convert words to values, in numbers, or signal patterns. The process of converting data to something a computer can understand is referred to as "pre-processing." One of the major forms of pre-processing is going to be filtering out useless data. In natural language processing, useless words (data), are referred to as stop words.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
example_sentence ="This is an example showing off stop word filtration"

#stop words
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'why', 'which', 'do', 'her', 'until', 'those', 'he', 'we', 'won', 'doing', 't', 'aren', 'down', 'hasn', 'their', 'as', 'i', 'below', 'then', 'theirs', 'ourselves', 'about', 'doesn', 'y', 'our', 'should', 'o', 'no', 'few', 'before', 'in', 'weren', 'above', 'hers', 'further', 'me', 'over', 'isn', 'these', 'don', 's', 'him', 'most', 'your', 'am', 'yours', 'what', 'is', 'you', 'up', 'or', 'wasn', 'this', 'but', 'against', 'through', 'not', 'now', 'herself', 'his', 'd', 'didn', 'shan', 'for', 'it', 'have', 'to', 'because', 'if', 'such', 'does', 'couldn', 'so', 'were', 'ain', 'all', 'my', 'its', 'shouldn', 'needn', 'how', 'has', 'of', 'on', 'from', 'was', 'and', 'only', 'having', 'where', 'whom', 'when', 'been', 'who', 'again', 'themselves', 'them', 'under', 'here', 'mightn', 'nor', 'at', 'be', 'once', 've', 'just', 'very', 'hadn', 'a', 'by', 'after', 'some', 'm', 'can', 'himself', 'the', 'haven', 'ours', 'myself', 'are', 'being', 'had', 'during', 'any', 'ma', 'an', 'too', 'yourself', 'wouldn', 'other', 'own', 'there', 'mustn', 'while', 'same', 'itself', 'yourselves', 'off', 'will', 'did', 'that', 'with', 're', 'both', 'more', 'each', 'she', 'they', 'll', 'out', 'between', 'into', 'than'}

# %%
word = word_tokenize(example_sentence)

# %%
filtered_sentence = []

# %%
for w in word:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
filtered_sentence
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration']

# %%
filtered_sentence = [w for w in word if not w in stop_words]

# %%
filtered_sentence
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration']

# %% [markdown]
# # Stemming

# %% [markdown]
# The idea of stemming is a sort of normalizing method. Many variations of words carry the same meaning, other than when tense is involved.
#
# The reason why we stem is to shorten the lookup, and normalize sentences.
#
# Consider:
#
# I was taking a ride in the car.
# I was riding in the car.
#
# One of the most popular stemming algorithms is the Porter stemmer, which has been around since 1979.

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
ps = PorterStemmer()

# %%
ex_words = ["python","pythoning","pythoned","pythonly"]

# %%
for word in ex_words:
    print(ps.stem(word))
# Out:
# python
# python
# python
# pythonli

# %%
 new_text = "It is important to by very pythonly while you are pythoning with python. All pythoners have pythoned poorly at least once."

# %%
words = word_tokenize(new_text)

# %%
for word in words:
    print(ps.stem(word))
# Out:
# It
# is
# import
# to
# by
# veri
# pythonli
# while
# you
# are
# python
# with
# python
# .
# all
# python
# have
# python
# poorli
# at
# least
# onc
# .

# %% [markdown]
# # Part of Speech Tagging

# %% [markdown]
# One of the more powerful aspects of the NLTK module is the Part of Speech tagging that it can do for you. This means labeling words in a sentence as nouns, adjectives, verbs...etc.

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %% [markdown]
# PunktSentence Tokenizer is a unsupervised machine learning sentence tokenizer. We can re train it.

# %%
sample_text = state_union.raw("2006-GWBush.txt")

# %%
train_text = state_union.raw("2005-GWBush.txt")

# %%
custom_text_tokenizer = PunktSentenceTokenizer(train_text)

# %%
custom_text_tokenizer

# %%
tokenized = custom_text_tokenizer.tokenize(sample_text)

# %%
tokenized
# Out:
# ["PRESIDENT GEORGE W. BUSH'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all.",
#  'Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream.',
#  'Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King.',
#  '(Applause.)',
#  'President George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan.',
#  '31, 2006.',
#  "White House photo by Eric DraperEvery time I'm invited to this rostrum, I'm humbled by the privilege, and mindful of the history we've seen together.",
#  'We have gathered under this Capitol dome in moments of national mourning and national achievement.',
#  'We have served America through one of the most consequential periods of our history -- and it has been my honor to serve with you.',
#  'In a system of two parties, two chambers, and two elected branches, there will always be differences and debate.',
#  'But even tough debates can be conducted in a civil tone, and our differences cannot be allowed to harden into anger.',
#  'To confront the great issues before us, we must act in a spirit of goodwill and respect for one another -- and I will do my part.',
#  'Tonight the state of our Union is strong -- and together we will make it stronger.',
#  '(Applause.)',
#  'In this decisive year, you and I will make choices that determine both the future and the character of our country.',
#  'We will choose to act confidently in pursuing the enemies of freedom -- or retreat from our duties in the hope of an easier life.',
#  'We will choose to build our prosperity by leading the world economy -- or shut ourselves off from trade and opportunity.',
#  'In a complex and challenging time, the road of isolationism and protectionism may seem broad and inviting -- yet it ends in danger and decline.',
#  'The only way to protect our people, the only way to secure the peace, the only way to control our destiny is by our leadership -- so the United States of America will continue to lead.',
#  '(Applause.)',
#  'Abroad, our nation is committed to an historic, long-term goal -- we seek the end of tyranny in our world.',
#  'Some dismiss that goal as misguided idealism.',
#  'In reality, the future security of America depends on it.',
#  'On September the 11th, 2001, we found that problems originating in a failed and oppressive state 7,000 miles away could bring murder and destruction to our country.',
#  'Dictatorships shelter terrorists, and feed resentment and radicalism, and seek weapons of mass destruction.',
#  'Democracies replace resentment with hope, respect the rights of their citizens and their neighbors, and join the fight against terror.',
#  "Every step toward freedom in the world makes our country safer -- so we will act boldly in freedom's cause.",
#  '(Applause.)',
#  'Far from being a hopeless dream, the advance of freedom is the great story of our time.',
#  'In 1945, there were about two dozen lonely democracies in the world.',
#  'Today, there are 122.',
#  "And we're writing a new chapter in the story of self-government -- with women lining up to vote in Afghanistan, and millions of Iraqis marking their liberty with purple ink, and men and women from Lebanon to Egypt debating the rights of individuals and the necessity of freedom.",
#  'At the start of 2006, more than half the people of our world live in democratic nations.',
#  'And we do not forget the other half -- in places like Syria and Burma, Zimbabwe, North Korea, and Iran -- because the demands of justice, and the peace of this world, require their freedom, as well.',
#  '(Applause.)',
#  'President George W. Bush delivers his State of the Union Address at the Capitol, Tuesday, Jan.',
#  '31, 2006.',
#  'White House photo by Eric Draper No one can deny the success of freedom, but some men rage and fight against it.',
#  'And one of the main sources of reaction and opposition is radical Islam -- the perversion by a few of a noble faith into an ideology of terror and death.',
#  'Terrorists like bin Laden are serious about mass murder -- and all of us must take their declared intentions seriously.',
#  'They seek to impose a heartless system of totalitarian control throughout the Middle East, and arm themselves with weapons of mass murder.',
#  'Their aim is to seize power in Iraq, and use it as a safe haven to launch attacks against America and the world.',
#  'Lacking the military strength to challenge us directly, the terrorists have chosen the weapon of fear.',
#  'When they murder children at a school in Beslan, or blow up commuters in London, or behead a bound captive, the terrorists hope these horrors will break our will, allowing the violent to inherit the Earth.',
#  'But they have miscalculated: We love our freedom, and we will fight to keep it.',
#  '(Applause.)',
#  'In a time of testing, we cannot find security by abandoning our commitments and retreating within our borders.',
#  'If we were to leave these vicious attackers alone, they would not leave us alone.',
#  'They would simply move the battlefield to our own shores.',
#  'There is no peace in retreat.',
#  'And there is no honor in retreat.',
#  'By allowing radical Islam to work its will -- by leaving an assaulted world to fend for itself -- we would signal to all that we no longer believe in our own ideals, or even in our own courage.',
#  'But our enemies and our friends can be certain: The United States will not retreat from the world, and we will never surrender to evil.',
#  '(Applause.)',
#  'America rejects the false comfort of isolationism.',
#  'We are the nation that saved liberty in Europe, and liberated death camps, and helped raise up democracies, and faced down an evil empire.',
#  'Once again, we accept the call of history to deliver the oppressed and move this world toward peace.',
#  'We remain on the offensive against terror networks.',
#  'We have killed or captured many of their leaders -- and for the others, their day will come.',
#  'President George W. Bush greets members of Congress after his State of the Union Address at the Capitol, Tuesday, Jan.',
#  '31, 2006.',
#  'White House photo by Eric Draper We remain on the offensive in Afghanistan, where a fine President and a National Assembly are fighting terror while building the institutions of a new democracy.',
#  "We're on the offensive in Iraq, with a clear plan for victory.",
#  "First, we're helping Iraqis build an inclusive government, so that old resentments will be eased and the insurgency will be marginalized.",
#  "Second, we're continuing reconstruction efforts, and helping the Iraqi government to fight corruption and build a modern economy, so all Iraqis can experience the benefits of freedom.",
#  "And, third, we're striking terrorist targets while we train Iraqi forces that are increasingly capable of defeating the enemy.",
#  'Iraqis are showing their courage every day, and we are proud to be their allies in the cause of freedom.',
#  '(Applause.)',
#  'Our work in Iraq is difficult because our enemy is brutal.',
#  'But that brutality has not stopped the dramatic progress of a new democracy.',
#  'In less than three years, the nation has gone from dictatorship to liberation, to sovereignty, to a constitution, to national elections.',
#  'At the same time, our coalition has been relentless in shutting off terrorist infiltration, clearing out insurgent strongholds, and turning over territory to Iraqi security forces.',
#  'I am confident in our plan for victory; I am confident in the will of the Iraqi people; I am confident in the skill and spirit of our military.',
#  'Fellow citizens, we are in this fight to win, and we are winning.',
#  '(Applause.)',
#  'The road of victory is the road that will take our troops home.',
#  'As we make progress on the ground, and Iraqi forces increasingly take the lead, we should be able to further decrease our troop levels -- but those decisions will be made by our military commanders, not by politicians in Washington, D.C.',
#  '(Applause.)',
#  'Our coalition has learned from our experience in Iraq.',
#  "We've adjusted our military tactics and changed our approach to reconstruction.",
#  'Along the way, we have benefitted from responsible criticism and counsel offered by members of Congress of both parties.',
#  'In the coming year, I will continue to reach out and seek your good advice.',
#  'Yet, there is a difference between responsible criticism that aims for success, and defeatism that refuses to acknowledge anything but failure.',
#  '(Applause.)',
#  'Hindsight alone is not wisdom, and second-guessing is not a strategy.',
#  '(Applause.)',
#  'With so much in the balance, those of us in public office have a duty to speak with candor.',
#  'A sudden withdrawal of our forces from Iraq would abandon our Iraqi allies to death and prison, would put men like bin Laden and Zarqawi in charge of a strategic country, and show that a pledge from America means little.',
#  'Members of Congress, however we feel about the decisions and debates of the past, our nation has only one option: We must keep our word, defeat our enemies, and stand behind the American military in this vital mission.',
#  '(Applause.)',
#  'Laura Bush is applauded as she is introduced Tuesday evening, Jan.',
#  '31, 2006 during the State of the Union Address at United States Capitol in Washington.',
#  'White House photo by Eric Draper Our men and women in uniform are making sacrifices -- and showing a sense of duty stronger than all fear.',
#  "They know what it's like to fight house to house in a maze of streets, to wear heavy gear in the desert heat, to see a comrade killed by a roadside bomb.",
#  'And those who know the costs also know the stakes.',
#  'Marine Staff Sergeant Dan Clay was killed last month fighting in Fallujah.',
#  'He left behind a letter to his family, but his words could just as well be addressed to every American.',
#  'Here is what Dan wrote: "I know what honor is.',
#  '... It has been an honor to protect and serve all of you.',
#  'I faced death with the secure knowledge that you would not have to....',
#  'Never falter!',
#  'Don\'t hesitate to honor and support those of us who have the honor of protecting that which is worth protecting."',
#  "Staff Sergeant Dan Clay's wife, Lisa, and his mom and dad, Sara Jo and Bud, are with us this evening.",
#  'Welcome.',
#  '(Applause.)',
#  'Our nation is grateful to the fallen, who live in the memory of our country.',
#  "We're grateful to all who volunteer to wear our nation's uniform -- and as we honor our brave troops, let us never forget the sacrifices of America's military families.",
#  '(Applause.)',
#  'Our offensive against terror involves more than military action.',
#  'Ultimately, the only way to defeat the terrorists is to defeat their dark vision of hatred and fear by offering the hopeful alternative of political freedom and peaceful change.',
#  'So the United States of America supports democratic reform across the broader Middle East.',
#  'Elections are vital, but they are only the beginning.',
#  'Raising up a democracy requires the rule of law, and protection of minorities, and strong, accountable institutions that last longer than a single vote.',
#  'The great people of Egypt have voted in a multi-party presidential election -- and now their government should open paths of peaceful opposition that will reduce the appeal of radicalism.',
#  'The Palestinian people have voted in elections.',
#  'And now the leaders of Hamas must recognize Israel, disarm, reject terrorism, and work for lasting peace.',
#  '(Applause.)',
#  'Saudi Arabia has taken the first steps of reform -- now it can offer its people a better future by pressing forward with those efforts.',
#  'Democracies in the Middle East will not look like our own, because they will reflect the traditions of their own citizens.',
#  'Yet liberty is the future of every nation in the Middle East, because liberty is the right and hope of all humanity.',
#  '(Applause.)',
#  'President George W. Bush waves toward the upper visitors gallery of the House Chamber following his State of the Union remarks Tuesday, Jan.',
#  '31, 2006 at the United States Capitol.',
#  'White House photo by Eric Draper The same is true of Iran, a nation now held hostage by a small clerical elite that is isolating and repressing its people.',
#  'The regime in that country sponsors terrorists in the Palestinian territories and in Lebanon -- and that must come to an end.',
#  '(Applause.)',
#  'The Iranian government is defying the world with its nuclear ambitions, and the nations of the world must not permit the Iranian regime to gain nuclear weapons.',
#  '(Applause.)',
#  'America will continue to rally the world to confront these threats.',
#  'Tonight, let me speak directly to the citizens of Iran: America respects you, and we respect your country.',
#  'We respect your right to choose your own future and win your own freedom.',
#  'And our nation hopes one day to be the closest of friends with a free and democratic Iran.',
#  '(Applause.)',
#  'To overcome dangers in our world, we must also take the offensive by encouraging economic progress, and fighting disease, and spreading hope in hopeless lands.',
#  'Isolationism would not only tie our hands in fighting enemies, it would keep us from helping our friends in desperate need.',
#  'We show compassion abroad because Americans believe in the God-given dignity and worth of a villager with HIV/AIDS, or an infant with malaria, or a refugee fleeing genocide, or a young girl sold into slavery.',
#  'We also show compassion abroad because regions overwhelmed by poverty, corruption, and despair are sources of terrorism, and organized crime, and human trafficking, and the drug trade.',
#  'In recent years, you and I have taken unprecedented action to fight AIDS and malaria, expand the education of girls, and reward developing nations that are moving forward with economic and political reform.',
#  'For people everywhere, the United States is a partner for a better life.',
#  'Short-changing these efforts would increase the suffering and chaos of our world, undercut our long-term security, and dull the conscience of our country.',
#  'I urge members of Congress to serve the interests of America by showing the compassion of America.',
#  'Our country must also remain on the offensive against terrorism here at home.',
#  'The enemy has not lost the desire or capability to attack us.',
#  'Fortunately, this nation has superb professionals in law enforcement, intelligence, the military, and homeland security.',
#  'These men and women are dedicating their lives, protecting us all, and they deserve our support and our thanks.',
#  '(Applause.)',
#  'They also deserve the same tools they already use to fight drug trafficking and organized crime -- so I ask you to reauthorize the Patriot Act.',
#  '(Applause.)',
#  'It is said that prior to the attacks of September the 11th, our government failed to connect the dots of the conspiracy.',
#  'We now know that two of the hijackers in the United States placed telephone calls to al Qaeda operatives overseas.',
#  'But we did not know about their plans until it was too late.',
#  'So to prevent another attack -- based on authority given to me by the Constitution and by statute -- I have authorized a terrorist surveillance program to aggressively pursue the international communications of suspected al Qaeda operatives and affiliates to and from America.',
#  'Previous Presidents have used the same constitutional authority I have, and federal courts have approved the use of that authority.',
#  'Appropriate members of Congress have been kept informed.',
#  'The terrorist surveillance program has helped prevent terrorist attacks.',
#  'It remains essential to the security of America.',
#  'If there are people inside our country who are talking with al Qaeda, we want to know about it, because we will not sit back and wait to be hit again.',
#  '(Applause.)',
#  'In all these areas -- from the disruption of terror networks, to victory in Iraq, to the spread of freedom and hope in troubled regions -- we need the support of our friends and allies.',
#  'To draw that support, we must always be clear in our principles and willing to act.',
#  'The only alternative to American leadership is a dramatically more dangerous and anxious world.',
#  'Yet we also choose to lead because it is a privilege to serve the values that gave us birth.',
#  'American leaders -- from Roosevelt to Truman to Kennedy to Reagan -- rejected isolation and retreat, because they knew that America is always more secure when freedom is on the march.',
#  'Our own generation is in a long war against a determined enemy -- a war that will be fought by Presidents of both parties, who will need steady bipartisan support from the Congress.',
#  'And tonight I ask for yours.',
#  'Together, let us protect our country, support the men and women who defend us, and lead this world toward freedom.',
#  '(Applause.)',
#  'Here at home, America also has a great opportunity: We will build the prosperity of our country by strengthening our economic leadership in the world.',
#  'Our economy is healthy and vigorous, and growing faster than other major industrialized nations.',
#  'In the last two-and-a-half years, America has created 4.6 million new jobs -- more than Japan and the European Union combined.',
#  '(Applause.)',
#  'Even in the face of higher energy prices and natural disasters, the American people have turned in an economic performance that is the envy of the world.',
#  'The American economy is preeminent, but we cannot afford to be complacent.',
#  "In a dynamic world economy, we are seeing new competitors, like China and India, and this creates uncertainty, which makes it easier to feed people's fears.",
#  "So we're seeing some old temptations return.",
#  'Protectionists want to escape competition, pretending that we can keep our high standard of living while walling off our economy.',
#  'Others say that the government needs to take a larger role in directing the economy, centralizing more power in Washington and increasing taxes.',
#  'We hear claims that immigrants are somehow bad for the economy -- even though this economy could not function without them.',
#  '(Applause.)',
#  'All these are forms of economic retreat, and they lead in the same direction -- toward a stagnant and second-rate economy.',
#  'Tonight I will set out a better path: an agenda for a nation that competes with confidence; an agenda that will raise standards of living and generate new jobs.',
#  'Americans should not fear our economic future, because we intend to shape it.',
#  'Keeping America competitive begins with keeping our economy growing.',
#  'And our economy grows when Americans have more of their own money to spend, save, and invest.',
#  'In the last five years, the tax relief you passed has left $880 billion in the hands of American workers, investors, small businesses, and families -- and they have used it to help produce more than four years of uninterrupted economic growth.',
#  '(Applause.)',
#  'Yet the tax relief is set to expire in the next few years.',
#  'If we do nothing, American families will face a massive tax increase they do not expect and will not welcome.',
#  'Because America needs more than a temporary expansion, we need more than temporary tax relief.',
#  'I urge the Congress to act responsibly, and make the tax cuts permanent.',
#  '(Applause.)',
#  'Keeping America competitive requires us to be good stewards of tax dollars.',
#  "Every year of my presidency, we've reduced the growth of non-security discretionary spending, and last year you passed bills that cut this spending.",
#  'This year my budget will cut it again, and reduce or eliminate more than 140 programs that are performing poorly or not fulfilling essential priorities.',
#  'By passing these reforms, we will save the American taxpayer another $14 billion next year, and stay on track to cut the deficit in half by 2009.',
#  '(Applause.)',
#  'I am pleased that members of Congress are working on earmark reform, because the federal budget has too many special interest projects.',
#  '(Applause.)',
#  'And we can tackle this problem together, if you pass the line-item veto.',
#  '(Applause.)',
#  'We must also confront the larger challenge of mandatory spending, or entitlements.',
#  "This year, the first of about 78 million baby boomers turn 60, including two of my Dad's favorite people -- me and President Clinton.",
#  '(Laughter.)',
#  'This milestone is more than a personal crisis -- (laughter) -- it is a national challenge.',
#  'The retirement of the baby boom generation will put unprecedented strains on the federal government.',
#  'By 2030, spending for Social Security, Medicare and Medicaid alone will be almost 60 percent of the entire federal budget.',
#  'And that will present future Congresses with impossible choices -- staggering tax increases, immense deficits, or deep cuts in every category of spending.',
#  'Congress did not act last year on my proposal to save Social Security -- (applause) -- yet the rising cost of entitlements is a problem that is not going away.',
#  '(Applause.)',
#  'And every year we fail to act, the situation gets worse.',
#  'So tonight, I ask you to join me in creating a commission to examine the full impact of baby boom retirements on Social Security, Medicare, and Medicaid.',
#  'This commission should include members of Congress of both parties, and offer bipartisan solutions.',
#  'We need to put aside partisan politics and work together and get this problem solved.',
#  '(Applause.)',
#  'Keeping America competitive requires us to open more markets for all that Americans make and grow.',
#  'One out of every five factory jobs in America is related to global trade, and we want people everywhere to buy American.',
#  'With open markets and a level playing field, no one can out-produce or out-compete the American worker.',
#  '(Applause.)',
#  'Keeping America competitive requires an immigration system that upholds our laws, reflects our values, and serves the interests of our economy.',
#  'Our nation needs orderly and secure borders.',
#  '(Applause.)',
#  'To meet this goal, we must have stronger immigration enforcement and border protection.',
#  '(Applause.)',
#  'And we must have a rational, humane guest worker program that rejects amnesty, allows temporary jobs for people who seek them legally, and reduces smuggling and crime at the border.',
#  '(Applause.)',
#  'Keeping America competitive requires affordable health care.',
#  '(Applause.)',
#  'Our government has a responsibility to provide health care for the poor and the elderly, and we are meeting that responsibility.',
#  '(Applause.)',
#  'For all Americans -- for all Americans, we must confront the rising cost of care, strengthen the doctor-patient relationship, and help people afford the insurance coverage they need.',
#  '(Applause.)',
#  'We will make wider use of electronic records and other health information technology, to help control costs and reduce dangerous medical errors.',
#  'We will strengthen health savings accounts -- making sure individuals and small business employees can buy insurance with the same advantages that people working for big businesses now get.',
#  '(Applause.)',
#  'We will do more to make this coverage portable, so workers can switch jobs without having to worry about losing their health insurance.',
#  '(Applause.)',
#  'And because lawsuits are driving many good doctors out of practice -- leaving women in nearly 1,500 American counties without a single OB/GYN -- I ask the Congress to pass medical liability reform this year.',
#  '(Applause.)',
#  'Keeping America competitive requires affordable energy.',
#  'And here we have a serious problem: America is addicted to oil, which is often imported from unstable parts of the world.',
#  'The best way to break this addiction is through technology.',
#  'Since 2001, we have spent nearly $10 billion to develop cleaner, cheaper, and more reliable alternative energy sources -- and we are on the threshold of incredible advances.',
#  'So tonight, I announce the Advanced Energy Initiative -- a 22-percent increase in clean-energy research -- at the Department of Energy, to push for breakthroughs in two vital areas.',
#  'To change how we power our homes and offices, we will invest more in zero-emission coal-fired plants, revolutionary solar and wind technologies, and clean, safe nuclear energy.',
#  '(Applause.)',
#  'We must also change how we power our automobiles.',
#  'We will increase our research in better batteries for hybrid and electric cars, and in pollution-free cars that run on hydrogen.',
#  "We'll also fund additional research in cutting-edge methods of producing ethanol, not just from corn, but from wood chips and stalks, or switch grass.",
#  'Our goal is to make this new kind of ethanol practical and competitive within six years.',
#  '(Applause.)',
#  'Breakthroughs on this and other new technologies will help us reach another great goal: to replace more than 75 percent of our oil imports from the Middle East by 2025.',
#  '(Applause.)',
#  'By applying the talent and technology of America, this country can dramatically improve our environment, move beyond a petroleum-based economy, and make our dependence on Middle Eastern oil a thing of the past.',
#  '(Applause.)',
#  'And to keep America competitive, one commitment is necessary above all: We must continue to lead the world in human talent and creativity.',
#  "Our greatest advantage in the world has always been our educated, hardworking, ambitious people -- and we're going to keep that edge.",
#  "Tonight I announce an American Competitiveness Initiative, to encourage innovation throughout our economy, and to give our nation's children a firm grounding in math and science.",
#  '(Applause.)',
#  'First, I propose to double the federal commitment to the most critical basic research programs in the physical sciences over the next 10 years.',
#  "This funding will support the work of America's most creative minds as they explore promising areas such as nanotechnology, supercomputing, and alternative energy sources.",
#  'Second, I propose to make permanent the research and development tax credit -- (applause) -- to encourage bolder private-sector initiatives in technology.',
#  'With more research in both the public and private sectors, we will improve our quality of life -- and ensure that America will lead the world in opportunity and innovation for decades to come.',
#  '(Applause.)',
#  'Third, we need to encourage children to take more math and science, and to make sure those courses are rigorous enough to compete with other nations.',
#  "We've made a good start in the early grades with the No Child Left Behind Act, which is raising standards and lifting test scores across our country.",
#  'Tonight I propose to train 70,000 high school teachers to lead advanced-placement courses in math and science, bring 30,000 math and science professionals to teach in classrooms, and give early help to students who struggle with math, so they have a better chance at good, high-wage jobs.',
#  "If we ensure that America's children succeed in life, they will ensure that America succeeds in the world.",
#  '(Applause.)',
#  'Preparing our nation to compete in the world is a goal that all of us can share.',
#  'I urge you to support the American Competitiveness Initiative, and together we will show the world what the American people can achieve.',
#  'America is a great force for freedom and prosperity.',
#  'Yet our greatness is not measured in power or luxuries, but by who we are and how we treat one another.',
#  'So we strive to be a compassionate, decent, hopeful society.',
#  'In recent years, America has become a more hopeful nation.',
#  'Violent crime rates have fallen to their lowest levels since the 1970s.',
#  'Welfare cases have dropped by more than half over the past decade.',
#  'Drug use among youth is down 19 percent since 2001.',
#  'There are fewer abortions in America than at any point in the last three decades, and the number of children born to teenage mothers has been falling for a dozen years in a row.',
#  '(Applause.)',
#  'These gains are evidence of a quiet transformation -- a revolution of conscience, in which a rising generation is finding that a life of personal responsibility is a life of fulfillment.',
#  'Government has played a role.',
#  'Wise policies, such as welfare reform and drug education and support for abstinence and adoption have made a difference in the character of our country.',
#  'And everyone here tonight, Democrat and Republican, has a right to be proud of this record.',
#  '(Applause.)',
#  'Yet many Americans, especially parents, still have deep concerns about the direction of our culture, and the health of our most basic institutions.',
#  "They're concerned about unethical conduct by public officials, and discouraged by activist courts that try to redefine marriage.",
#  'They worry about children in our society who need direction and love, and about fellow citizens still displaced by natural disaster, and about suffering caused by treatable diseases.',
#  'As we look at these challenges, we must never give in to the belief that America is in decline, or that our culture is doomed to unravel.',
#  'The American people know better than that.',
#  'We have proven the pessimists wrong before -- and we will do it again.',
#  '(Applause.)',
#  'A hopeful society depends on courts that deliver equal justice under the law.',
#  'The Supreme Court now has two superb new members -- new members on its bench: Chief Justice John Roberts and Justice Sam Alito.',
#  '(Applause.)',
#  'I thank the Senate for confirming both of them.',
#  'I will continue to nominate men and women who understand that judges must be servants of the law, and not legislate from the bench.',
#  '(Applause.)',
#  'Today marks the official retirement of a very special American.',
#  "For 24 years of faithful service to our nation, the United States is grateful to Justice Sandra Day O'Connor.",
#  '(Applause.)',
#  'A hopeful society has institutions of science and medicine that do not cut ethical corners, and that recognize the matchless value of every life.',
#  'Tonight I ask you to pass legislation to prohibit the most egregious abuses of medical research: human cloning in all its forms, creating or implanting embryos for experiments, creating human-animal hybrids, and buying, selling, or patenting human embryos.',
#  'Human life is a gift from our Creator -- and that gift should never be discarded, devalued or put up for sale.',
#  '(Applause.)',
#  'A hopeful society expects elected officials to uphold the public trust.',
#  '(Applause.)',
#  'Honorable people in both parties are working on reforms to strengthen the ethical standards of Washington -- I support your efforts.',
#  'Each of us has made a pledge to be worthy of public responsibility -- and that is a pledge we must never forget, never dismiss, and never betray.',
#  '(Applause.)',
#  'As we renew the promise of our institutions, let us also show the character of America in our compassion and care for one another.',
#  'A hopeful society gives special attention to children who lack direction and love.',
#  "Through the Helping America's Youth Initiative, we are encouraging caring adults to get involved in the life of a child -- and this good work is being led by our First Lady, Laura Bush.",
#  '(Applause.)',
#  "This year we will add resources to encourage young people to stay in school, so more of America's youth can raise their sights and achieve their dreams.",
#  "A hopeful society comes to the aid of fellow citizens in times of suffering and emergency -- and stays at it until they're back on their feet.",
#  'So far the federal government has committed $85 billion to the people of the Gulf Coast and New Orleans.',
#  "We're removing debris and repairing highways and rebuilding stronger levees.",
#  "We're providing business loans and housing assistance.",
#  'Yet as we meet these immediate needs, we must also address deeper challenges that existed before the storm arrived.',
#  'In New Orleans and in other places, many of our fellow citizens have felt excluded from the promise of our country.',
#  'The answer is not only temporary relief, but schools that teach every child, and job skills that bring upward mobility, and more opportunities to own a home and start a business.',
#  'As we recover from a disaster, let us also work for the day when all Americans are protected by justice, equal in hope, and rich in opportunity.',
#  '(Applause.)',
#  'A hopeful society acts boldly to fight diseases like HIV/AIDS, which can be prevented, and treated, and defeated.',
#  'More than a million Americans live with HIV, and half of all AIDS cases occur among African Americans.',
#  'I ask Congress to reform and reauthorize the Ryan White Act, and provide new funding to states, so we end the waiting lists for AIDS medicines in America.',
#  '(Applause.)',
#  'We will also lead a nationwide effort, working closely with African American churches and faith-based groups, to deliver rapid HIV tests to millions, end the stigma of AIDS, and come closer to the day when there are no new infections in America.',
#  '(Applause.)',
#  "Fellow citizens, we've been called to leadership in a period of consequence.",
#  "We've entered a great ideological conflict we did nothing to invite.",
#  'We see great changes in science and commerce that will influence all our lives.',
#  'Sometimes it can seem that history is turning in a wide arc, toward an unknown shore.',
#  'Yet the destination of history is determined by human action, and every great movement of history comes to a point of choosing.',
#  'Lincoln could have accepted peace at the cost of disunity and continued slavery.',
#  'Martin Luther King could have stopped at Birmingham or at Selma, and achieved only half a victory over segregation.',
#  'The United States could have accepted the permanent division of Europe, and been complicit in the oppression of others.',
#  'Today, having come far in our own historical journey, we must decide: Will we turn back, or finish well?',
#  'Before history is written down in books, it is written in courage.',
#  'Like Americans before us, we will show that courage and we will finish well.',
#  "We will lead freedom's advance.",
#  'We will compete and excel in the global economy.',
#  'We will renew the defining moral commitments of this land.',
#  'And so we move forward -- optimistic about our country, faithful to its cause, and confident of the victories to come.',
#  'May God bless America.',
#  '(Applause.)']

# %%
# creating a function to tokenize

def part_of_speech(document):
    try:
        for i in document:
            words = nltk.word_tokenize(document)
            tagged = nltk.pos_tag(words)
            print(tagged)
        
    except Exception as e:
        print(str(e))

# %%
part_of_speech(tokenized)
# Out:
# expected string or bytes-like object

# %% [markdown]
# This error occurs because the tagging could not be done on the number

# %%
import re
letters_only = re.sub("[^a-zA-Z]",  # Search for all non-letters
                          " ",          # Replace all non-letters with spaces
                          str(tokenized))

# %%
letters_only
# Out:
# '  PRESIDENT GEORGE W  BUSH S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION n  nJanuary          n nTHE PRESIDENT  Thank you all     Mr  Speaker  Vice President Cheney  members of Congress  members of the Supreme Court and diplomatic corps  distinguished guests  and fellow citizens  Today our nation lost a beloved  graceful  courageous woman who called America to its founding ideals and carried on a noble dream     Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago  and we are grateful for the good life of Coretta Scott King      Applause      President George W  Bush reacts to applause during his State of the Union Address at the Capitol  Tuesday  Jan                  White House photo by Eric DraperEvery time I m invited to this rostrum  I m humbled by the privilege  and mindful of the history we ve seen together     We have gathered under this Capitol dome in moments of national mourning and national achievement     We have served America through one of the most consequential periods of our history    and it has been my honor to serve with you     In a system of two parties  two chambers  and two elected branches  there will always be differences and debate     But even tough debates can be conducted in a civil tone  and our differences cannot be allowed to harden into anger     To confront the great issues before us  we must act in a spirit of goodwill and respect for one another    and I will do my part     Tonight the state of our Union is strong    and together we will make it stronger      Applause      In this decisive year  you and I will make choices that determine both the future and the character of our country     We will choose to act confidently in pursuing the enemies of freedom    or retreat from our duties in the hope of an easier life     We will choose to build our prosperity by leading the world economy    or shut ourselves off from trade and opportunity     In a complex and challenging time  the road of isolationism and protectionism may seem broad and inviting    yet it ends in danger and decline     The only way to protect our people  the only way to secure the peace  the only way to control our destiny is by our leadership    so the United States of America will continue to lead      Applause      Abroad  our nation is committed to an historic  long term goal    we seek the end of tyranny in our world     Some dismiss that goal as misguided idealism     In reality  the future security of America depends on it     On September the   th        we found that problems originating in a failed and oppressive state       miles away could bring murder and destruction to our country     Dictatorships shelter terrorists  and feed resentment and radicalism  and seek weapons of mass destruction     Democracies replace resentment with hope  respect the rights of their citizens and their neighbors  and join the fight against terror     Every step toward freedom in the world makes our country safer    so we will act boldly in freedom s cause      Applause      Far from being a hopeless dream  the advance of freedom is the great story of our time     In       there were about two dozen lonely democracies in the world     Today  there are         And we re writing a new chapter in the story of self government    with women lining up to vote in Afghanistan  and millions of Iraqis marking their liberty with purple ink  and men and women from Lebanon to Egypt debating the rights of individuals and the necessity of freedom     At the start of       more than half the people of our world live in democratic nations     And we do not forget the other half    in places like Syria and Burma  Zimbabwe  North Korea  and Iran    because the demands of justice  and the peace of this world  require their freedom  as well      Applause      President George W  Bush delivers his State of the Union Address at the Capitol  Tuesday  Jan                  White Hous ...

# %%
part_of_speech(letters_only)
# Out:
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# [('PRESIDENT', 'NNP'), ('GEORGE', 'NNP'), ('W', 'NNP'), ('BUSH', 'NNP'), ('S', 'NNP'), ('ADDRESS', 'NNP'), ('BEFORE', 'IN'), ('A', 'NNP'), ('JOINT', 'NNP'), ('SESSION', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('CONGRESS', 'NNP'), ('ON', 'NNP'), ('THE', 'NNP'), ('STATE', 'NNP'), ('OF', 'IN'), ('THE', 'NNP'), ('UNION', 'NNP'), ('n', 'IN'), ('nJanuary', 'JJ'), ('n', 'JJ'), ('nTHE', 'FW'), ('PRESIDENT', 'NNP'), ('Thank', 'NNP'), ('you', 'PRP'), ('all', 'DT'), ('Mr', 'NNP'), ('Speaker', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('Cheney', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('Congress', 'NNP'), ('members', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Supreme', 'NNP'), ('Court', 'NNP'), ('and', 'CC'), ('diplomatic', 'JJ'), ('corps', 'NN'), ('distinguished', 'VBN'), ('guests', 'NNS'), ('and', 'CC'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('Today', 'NNP'), ('our', 'PRP$'), ('nation', 'NN'), ('lost', 'VBD'), ('a', 'DT'), ('beloved', 'VBN'), ('graceful', 'JJ'), ('courageous', 'JJ'), ('woman', 'NN'), ('who', 'WP'), ('called', 'VBD'), ('America', 'NNP'), ('to', 'TO'), ('its', 'PRP$'), ('founding', 'NN'), ('ideals', 'NNS'), ('and', 'CC'), ('carried', 'VBD'), ('on', 'IN'), ('a', 'DT'), ('noble', 'JJ'), ('dream', 'NN'), ('Tonight', 'NNP'), ('we', 'PRP'), ('are', 'VBP'), ('comforted', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('hope', 'NN'), ('of', 'IN'), ('a', 'DT'), ('glad', 'JJ'), ('reunion', 'NN'), ('with', 'IN'), ('the', 'DT'), ('husband', 'NN'), ('who', 'WP'), ('was', 'VBD'), ('taken', 'VBN'), ('so', 'RB'), ('long', 'JJ'), ('ago', 'RB'), ('and', 'CC'), ('we', 'PRP'), ('are', 'VBP'), ('grateful', 'JJ'), ('for', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('life', 'NN'), ('of', 'IN'), ('Coretta', 'NNP'), ('Scott', 'NNP'), ('King', 'NNP'), ('Applause', 'NNP'), ('President', 'NNP'), ('George', 'NNP'), ('W', 'NNP'), ('Bush', 'NNP'), ('reacts', 'VBZ'), ('to', 'TO'), ('applause', 'VB'), ('during', 'IN'), ('his', 'PRP$'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('Address', 'NNP'), ('at', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Tuesday', 'NNP'), ('Jan', 'NNP'), ('White', 'NNP'), ('House', 'NNP'), ('photo', 'NN'), ('by', 'IN'), ('Eric', 'NNP'), ('DraperEvery', 'NNP'), ('time', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('invited', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('rostrum', 'NN'), ('I', 'PRP'), ('m', 'VBP'), ('humbled', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('privilege', 'NN'), ('and', 'CC'), ('mindful', 'NN'), ('of', 'IN'), ('the', 'DT'), ('history', 'NN'), ('we', 'PRP'), ('ve', 'VBP'), ('seen', 'VBN'), ('together', 'RB'), ('We', 'PRP'), ('have', 'VBP'), ('gathered', 'VBN'), ('under', 'IN'), ('this', 'DT'), ('Capitol', 'NNP'), ('dome', 'NN'), ('in', 'IN'), ('moments', 'NNS'), ('of', 'IN'), ('national', 'JJ'), ('mourning', 'NN'), ('and', 'CC'), ('national', 'JJ'), ('achievement', 'NN'), ('We', 'PRP'), ('have', 'VBP'), ('served', 'VBN'), ('America', 'NNP'), ('through', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('consequential', 'JJ'), ('periods', 'NNS'), ('of', 'IN'), ('our', 'PRP$'), ('history', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('my', 'PRP$'), ('honor', 'NN'), ('to', 'TO'), ('serve', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('In', 'IN'), ('a', 'DT'), ('system', 'NN'), ('of', 'IN'), ('two', 'CD'), ('parties', 'NNS'), ('two', 'CD'), ('chambers', 'NNS'), ('and', 'CC'), ('two', 'CD'), ('elected', 'JJ'), ('branches', 'NNS'), ('there', 'RB'), ('will', 'MD'), ('always', 'RB'), ('be', 'VB'), ('differences', 'NNS'), ('and', 'CC'), ('debate', 'NN'), ('But', 'CC'), ('even', 'RB'), ('tough', 'JJ'), ('debates', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('conducted', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('civil', 'JJ'), ('tone', 'NN'), ('and', 'CC'), ('our', 'PRP$'), ('differences', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('allowed', 'VBN'), ('to', 'TO'), ('harden', 'VB'), ('into', 'IN'), ('anger', 'NN'), ('To', 'TO'), ('confront', 'VB'), ('the', 'DT'), ('great', 'JJ'), ('issue ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-6e7ccdfca756> in <module>()
# ----> 1 part_of_speech(letters_only)
#
# <ipython-input-37-2ed035e5acbd> in part_of_speech(document)
#       5         for i in document:
#       6             words = nltk.word_tokenize(document)
# ----> 7             tagged = nltk.pos_tag(words)
#       8             print(tagged)
#       9
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\__init__.py in pos_tag(tokens, tagset, lang)
#     125     """
#     126     tagger = _get_tagger(lang)
# --> 127     return _pos_tag(tokens, tagset, tagger)
#     128
#     129
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\__init__.py in _pos_tag(tokens, tagset, tagger)
#      93
#      94 def _pos_tag(tokens, tagset, tagger):
# ---> 95     tagged_tokens = tagger.tag(tokens)
#      96     if tagset:
#      97         tagged_tokens = [(token, map_tag('en-ptb', tagset, tag)) for (token, tag) in tagged_tokens]
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\perceptron.py in tag(self, tokens)
#     155             if not tag:
#     156                 features = self._get_features(i, word, context, prev, prev2)
# --> 157                 tag = self.model.predict(features)
#     158             output.append((word, tag))
#     159             prev2 = prev
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\perceptron.py in predict(self, features)
#      54             weights = self.weights[feat]
#      55             for label, weight in weights.items():
# ---> 56                 scores[label] += value * weight
#      57         # Do a secondary alphabetic sort, for stability
#      58         return max(self.classes, key=lambda label: (scores[label], label))
#
# KeyboardInterrupt:

# %% [markdown]
# A problem with twitter analysis is that people don't punctuate. eg the names are written in small letters.

# %% [markdown]
# # Chunking

# %% [markdown]
#  we can do what is called chunking, and group words into hopefully meaningful chunks. One of the main goals of chunking is to group into what are known as "noun phrases." These are phrases of one or more words that contain a noun, maybe some descriptive words, maybe a verb, and maybe something like an adverb. The idea is to group nouns with the words that are in relation to them.

# %% [markdown]
# In order to chunk, we combine the part of speech tags with regular expressions. Mainly from regular expressions, we are going to utilize the following:

# %% [raw]
# + = match 1 or more
# ? = match 0 or 1 repetitions.
# * = match 0 or MORE repetitions
# . = Any character except a new line

# %% [raw]
# Cool, that helps us visually, but what if we want to access this data via our program? Well, what is happening here is our "chunked" variable is an NLTK tree. Each "chunk" and "non chunk" is a "subtree" of the tree. We can reference these by doing something like chunked.subtrees. We can then iterate through these subtrees like so:
#
# for subtree in chunked.subtrees():
#                 print(subtree)
#
# Next, we might be only interested in getting just the chunks, ignoring the rest. We can use the filter parameter in the chunked.subtrees() call.
#
# for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
#                 print(subtree)

# %%
def chunk(document):
    try:
        for i in document:
            words = nltk.word_tokenize(document)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
                print(subtree)
            
        
    except Exception as e:
        print(str(e))

# %%
chunk(letters_only)
# Out:
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# ...
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# (Chunk A/NNP JOINT/NNP SESSION/NNP)
# (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
# (Chunk THE/NNP UNION/NNP)
# (Chunk PRESIDENT/NNP Thank/NNP)
# (Chunk Mr/NNP Speaker/NNP Vice/NNP President/NNP Cheney/NNP)
# (Chunk Congress/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Today/NNP)
# (Chunk called/VBD America/NNP)
# (Chunk Tonight/NNP)
# (Chunk
#   Coretta/NNP
#   Scott/NNP
#   King/NNP
#   Applause/NNP
#   President/NNP
#   George/NNP
#   W/NNP
#   Bush/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP DraperEvery/NNP time/NN)
# (Chunk Capitol/NNP dome/NN)
# (Chunk have/VBP served/VBN America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Union/NNP)
# (Chunk Applause/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk lead/VB Applause/NNP Abroad/NNP)
# (Chunk America/NNP)
# (Chunk September/NNP)
# (Chunk Dictatorships/NNP shelter/NN)
# (Chunk Democracies/NNP)
# (Chunk Every/NNP step/NN)
# (Chunk Applause/NNP Far/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Egypt/NNP)
# (Chunk Syria/NNP)
# (Chunk Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (Chunk Iran/NNP)
# (Chunk well/RB Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP No/NNP one/NN)
# (Chunk Islam/NNP)
# (Chunk Laden/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Iraq/NNP)
# (Chunk America/NNP)
# (Chunk Beslan/NNP)
# (Chunk London/NNP)
# (Chunk Applause/NNP)
# (Chunk Islam/NNP)
# (Chunk United/NNP)
# (Chunk evil/VB Applause/NNP America/NNP)
# (Chunk Europe/NNP)
# (Chunk come/VB President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk Congress/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk Capitol/NNP Tuesday/NNP Jan/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Afghanistan/NNP)
# (Chunk President/NNP)
# (Chunk National/NNP Assembly/NNP)
# (Chunk Iraq/NNP)
# (Chunk First/NNP)
# (Chunk re/VBP helping/VBG Iraqis/NNP)
# (Chunk be/VB marginalized/VBN Second/NNP)
# (Chunk Iraqi/NNP government/NN)
# (Chunk Iraqis/NNP)
# (Chunk Iraqis/NNP)
# (Chunk Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP security/NN)
# (Chunk Iraqi/NNP)
# (Chunk Fellow/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Washington/NNP D/NNP C/NNP Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Hindsight/NNP)
# (Chunk Applause/NNP)
# (Chunk A/NNP)
# (Chunk Iraq/NNP)
# (Chunk Iraqi/NNP)
# (Chunk Laden/NNP)
# (Chunk Zarqawi/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Laura/NNP Bush/NNP)
# (Chunk is/VBZ introduced/VBN Tuesday/NNP)
# (Chunk evening/VBG Jan/NNP)
# (Chunk State/NNP)
# (Chunk Union/NNP Address/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP)
# (Chunk Washington/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Fallujah/NNP)
# (Chunk American/NNP)
# (Chunk Dan/NNP)
# (Chunk Never/NNP falter/NN)
# (Chunk Don/NNP t/NN)
# (Chunk protecting/VBG Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (Chunk Lisa/NNP)
# (Chunk Sara/NNP Jo/NNP)
# (Chunk Bud/NNP)
# (Chunk evening/VBG Welcome/NNP Applause/NNP)
# (Chunk America/NNP)
# (Chunk United/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Egypt/NNP)
# (Chunk Hamas/NNP)
# (Chunk recognize/VB Israel/NNP disarm/NN)
# (Chunk Applause/NNP Saudi/NNP Arabia/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Yet/NNP liberty/NN)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP President/NNP George/NNP W/NNP Bush/NNP)
# (Chunk House/NNP Chamber/NNP)
# (Chunk Union/NNP)
# (Chunk Tuesday/NNP Jan/NNP)
# (Chunk United/NNP)
# (Chunk Capitol/NNP White/NNP House/NNP photo/NN)
# (Chunk Eric/NNP Draper/NNP)
# (Chunk Iran/NNP)
# (Chunk Lebanon/NNP)
# (Chunk Applause/VBP America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Iran/NNP America/NNP)
# (Chunk Iran/NNP Applause/NNP)
# (Chunk Isolationism/NNP)
# (Chunk God/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk fight/VB AIDS/NNP)
# (Chunk United/NNP)
# (Chunk Short/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Patriot/NNP Act/NNP)
# (Chunk September/NNP)
# (Chunk United/NNP)
# (Chunk al/VB Qaeda/NNP)
# (Chunk Constitution/NNP)
# (Chunk Qaeda/NNP)
# (Chunk America/NNP Previous/NNP)
# (Chunk Appropriate/NNP)
# (Chunk Congress/NNP)
# (Chunk America/NNP)
# (Chunk Qaeda/NNP)
# (Chunk again/RB Applause/NNP)
# (Chunk Iraq/NNP)
# (Chunk Roosevelt/NNP)
# (Chunk Truman/NNP)
# (Chunk Kennedy/NNP)
# (Chunk Reagan/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Together/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Japan/NNP)
# (Chunk European/NNP Union/NNP)
# (Chunk combined/VBD Applause/NNP)
# (Chunk China/NNP)
# (Chunk India/NNP)
# (Chunk Washington/NNP)
# (Chunk Tonight/NNP)
# (Chunk Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk American/NNP taxpayer/NN)
# (Chunk Applause/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP)
# (Chunk Dad/NNP s/NN)
# (Chunk President/NNP Clinton/NNP Laughter/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk save/VB Social/NNP Security/NNP applause/NN)
# (Chunk away/RB Applause/NNP)
# (Chunk So/NNP)
# (Chunk Social/NNP Security/NNP Medicare/NNP)
# (Chunk Medicaid/NNP)
# (Chunk Congress/NNP)
# (Chunk solved/VBD Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk Applause/NNP)
# (Chunk OB/NNP GYN/NNP)
# (Chunk Congress/NNP)
# (Chunk Applause/NNP Keeping/NNP America/NNP)
# (Chunk America/NNP)
# (Chunk Advanced/NNP Energy/NNP Initiative/NNP)
# (Chunk Department/NNP)
# (Chunk Energy/NNP)
# (Chunk Applause/NNP Breakthroughs/NNP)
# (Chunk Middle/NNP East/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Middle/NNP Eastern/NNP oil/NN)
# (Chunk Applause/NNP)
# (Chunk keep/VB America/NNP)
# (Chunk Tonight/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk Applause/NNP First/NNP)
# (Chunk America/NNP)
# (Chunk Second/NNP)
# (Chunk America/NNP)
# (Chunk come/VB Applause/NNP Third/NNP)
# (Chunk No/NNP Child/NNP Left/NNP Behind/NNP Act/NNP)
# (Chunk Tonight/NNP)
# (Chunk America/NNP)
# (Chunk America/NNP)
# (Chunk Applause/NNP Preparing/NNP)
# (Chunk Competitiveness/NNP Initiative/NNP)
# (Chunk achieve/VB America/NNP)
# (Chunk America/NNP)
# (Chunk Violent/NNP crime/NN)
# (Chunk Welfare/NNP)
# (Chunk Drug/NNP use/NN)
# (Chunk America/NNP)
# (Chunk Government/NNP)
# (Chunk Wise/NNP)
# (Chunk Democrat/NNP)
# (Chunk Republican/NNP)
# (Chunk Applause/NNP Yet/NNP)
# (Chunk America/NNP)
# (Chunk A/NNP)
# (Chunk Supreme/NNP Court/NNP)
# (Chunk Chief/NNP Justice/NNP John/NNP Roberts/NNP)
# (Chunk Justice/NNP Sam/NNP Alito/NNP Applause/NNP)
# (Chunk Senate/NNP)
# (Chunk Applause/NNP Today/NNP)
# (Chunk American/NNP)
# (Chunk United/NNP)
# (Chunk
#   Justice/NNP
#   Sandra/NNP
#   Day/NNP
#   O/NNP
#   Connor/NNP
#   Applause/NNP
#   A/NNP)
# (Chunk Tonight/NNP)
# (Chunk Human/NNP life/NN)
# (Chunk Applause/NNP Honorable/NNP)
# (Chunk Washington/NNP)
# (Chunk Applause/NNP)
# (Chunk America/NNP)
# (Chunk Helping/NNP America/NNP)
# (Chunk s/VBD Youth/NNP Initiative/NNP)
# (Chunk First/NNP Lady/NNP Laura/NNP Bush/NNP)
# (Chunk America/NNP)
# (Chunk Gulf/NNP Coast/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk New/NNP Orleans/NNP)
# (Chunk HIV/NNP AIDS/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk ask/VBP Congress/NNP)
# (Chunk Ryan/NNP White/NNP Act/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP)
# (Chunk HIV/NNP)
# (Chunk AIDS/NNP)
# (Chunk America/NNP Applause/NNP Fellow/NNP)
# (Chunk choosing/VBG Lincoln/NNP)
# (Chunk Martin/NNP Luther/NNP King/NNP)
# (Chunk Birmingham/NNP)
# (Chunk Selma/NNP)
# (Chunk United/NNP)
# (Chunk Europe/NNP)
# (Chunk Today/NNP)
# (Chunk decide/VB Will/NNP)
# (Chunk come/VB May/NNP God/NNP bless/NN)
# (Chunk America/NNP Applause/NNP)
# (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-517e9ce53382> in <module>()
# ----> 1 chunk(letters_only)
#
# <ipython-input-44-d404da970ba4> in chunk(document)
#       8             chunked = chunkParser.parse(tagged)
#       9             for subtree in chunked.subtrees(filter=lambda t: t.label() == 'Chunk'):
# ---> 10                 print(subtree)
#      11
#      12
#
# C:\Users\aswat\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     350             is_child = (not self._is_master_process())
#     351             # only touch the buffer in the IO thread to avoid races
# --> 352             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     353             if is_child:
#     354                 # newlines imply flush in subprocesses
#
# C:\Users\aswat\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     188                 event_id = os.urandom(16)
#     189             self._events[event_id] = f
# --> 190             self._event_pipe.send(event_id)
#     191         else:
#     192             f()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq\backend\cython\socket.c:7305)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq\backend\cython\socket.c:7048)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy (zmq\backend\cython\socket.c:2920)()
#
# C:\Users\aswat\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\socket.c:9621)()
#
# KeyboardInterrupt:

# %% [markdown]
# # Chinking

# %% [markdown]
# Chinking is a lot like chunking, it is basically a way for you to remove a chunk from a chunk. The chunk that you remove from your chunk is your chink.

# %%
def chink(document):
    try:
        for i in document:
            words = nltk.word_tokenize(document)
            tagged = nltk.pos_tag(words)
            chunkGram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT>+{"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print(chunked)
            
        
    except Exception as e:
        print(str(e))

# %%
chink(letters_only)
# Out:
# (S
#   (Chunk PRESIDENT/NNP GEORGE/NNP W/NNP BUSH/NNP S/NNP ADDRESS/NNP)
#   BEFORE/IN
#   (Chunk A/NNP JOINT/NNP SESSION/NNP)
#   OF/IN
#   (Chunk THE/NNP CONGRESS/NNP ON/NNP THE/NNP STATE/NNP)
#   OF/IN
#   (Chunk THE/NNP UNION/NNP)
#   n/IN
#   (Chunk nJanuary/JJ n/JJ nTHE/FW PRESIDENT/NNP Thank/NNP you/PRP)
#   all/DT
#   (Chunk
#     Mr/NNP
#     Speaker/NNP
#     Vice/NNP
#     President/NNP
#     Cheney/NNP
#     members/NNS)
#   of/IN
#   (Chunk Congress/NNP members/NNS)
#   of/IN
#   the/DT
#   (Chunk Supreme/NNP Court/NNP and/CC diplomatic/JJ corps/NN)
#   distinguished/VBN
#   (Chunk
#     guests/NNS
#     and/CC
#     fellow/JJ
#     citizens/NNS
#     Today/NNP
#     our/PRP$
#     nation/NN)
#   lost/VBD
#   a/DT
#   beloved/VBN
#   (Chunk graceful/JJ courageous/JJ woman/NN who/WP)
#   called/VBD
#   (Chunk America/NNP to/TO its/PRP$ founding/NN ideals/NNS and/CC)
#   carried/VBD
#   on/IN
#   a/DT
#   (Chunk noble/JJ dream/NN Tonight/NNP we/PRP)
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   (Chunk hope/NN)
#   of/IN
#   a/DT
#   (Chunk glad/JJ reunion/NN)
#   with/IN
#   the/DT
#   (Chunk husband/NN who/WP)
#   was/VBD
#   taken/VBN
#   (Chunk so/RB long/JJ ago/RB and/CC we/PRP)
#   are/VBP
#   (Chunk grateful/JJ)
#   for/IN
#   the/DT
#   (Chunk good/JJ life/NN)
#   of/IN
#   (Chunk
#     Coretta/NNP
#     Scott/NNP
#     King/NNP
#     Applause/NNP
#     President/NNP
#     George/NNP
#     W/NNP
#     Bush/NNP)
#   reacts/VBZ
#   (Chunk to/TO)
#   applause/VB
#   during/IN
#   (Chunk his/PRP$ State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk
#     Capitol/NNP
#     Tuesday/NNP
#     Jan/NNP
#     White/NNP
#     House/NNP
#     photo/NN)
#   by/IN
#   (Chunk Eric/NNP DraperEvery/NNP time/NN I/PRP)
#   m/VBP
#   invited/VBN
#   (Chunk to/TO)
#   this/DT
#   (Chunk rostrum/NN I/PRP)
#   m/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   (Chunk privilege/NN and/CC mindful/NN)
#   of/IN
#   the/DT
#   (Chunk history/NN we/PRP)
#   ve/VBP
#   seen/VBN
#   (Chunk together/RB We/PRP)
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   (Chunk Capitol/NNP dome/NN)
#   in/IN
#   (Chunk moments/NNS)
#   of/IN
#   (Chunk
#     national/JJ
#     mourning/NN
#     and/CC
#     national/JJ
#     achievement/NN
#     We/PRP)
#   have/VBP
#   served/VBN
#   (Chunk America/NNP)
#   through/IN
#   (Chunk one/CD)
#   of/IN
#   the/DT
#   (Chunk most/RBS consequential/JJ periods/NNS)
#   of/IN
#   (Chunk our/PRP$ history/NN and/CC it/PRP)
#   has/VBZ
#   been/VBN
#   (Chunk my/PRP$ honor/NN to/TO)
#   serve/VB
#   with/IN
#   (Chunk you/PRP)
#   In/IN
#   a/DT
#   (Chunk system/NN)
#   of/IN
#   (Chunk
#     two/CD
#     parties/NNS
#     two/CD
#     chambers/NNS
#     and/CC
#     two/CD
#     elected/JJ
#     branches/NNS
#     there/RB
#     will/MD
#     always/RB)
#   be/VB
#   (Chunk
#     differences/NNS
#     and/CC
#     debate/NN
#     But/CC
#     even/RB
#     tough/JJ
#     debates/NNS
#     can/MD)
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   (Chunk
#     civil/JJ
#     tone/NN
#     and/CC
#     our/PRP$
#     differences/NNS
#     can/MD
#     not/RB)
#   be/VB
#   allowed/VBN
#   (Chunk to/TO)
#   harden/VB
#   into/IN
#   (Chunk anger/NN To/TO)
#   confront/VB
#   the/DT
#   (Chunk great/JJ issues/NNS)
#   before/IN
#   (Chunk us/PRP we/PRP must/MD)
#   act/VB
#   in/IN
#   a/DT
#   (Chunk spirit/NN)
#   of/IN
#   (Chunk goodwill/NN and/CC respect/NN)
#   for/IN
#   (Chunk one/CD)
#   another/DT
#   (Chunk and/CC I/PRP will/MD)
#   do/VB
#   (Chunk my/PRP$ part/NN Tonight/NNP)
#   the/DT
#   (Chunk state/NN)
#   of/IN
#   (Chunk our/PRP$ Union/NNP)
#   is/VBZ
#   (Chunk strong/JJ and/CC together/RB we/PRP will/MD)
#   make/VB
#   (Chunk it/PRP stronger/JJR Applause/NNP)
#   In/IN
#   this/DT
#   (Chunk decisive/JJ year/NN you/PRP and/CC I/PRP will/MD)
#   make/VB
#   (Chunk choices/NNS that/WDT)
#   determine/VBP
#   both/DT
#   the/DT
#   (Chunk future/NN and/CC)
#   the/DT
#   (Chunk character/NN)
#   of/IN
#   (Chunk our/PRP$ country/NN We/PRP will/MD)
#   choose/VB
#   (Chunk to/TO)
#   act/VB
#   (Chunk confidently/RB)
#   in/IN
#   pursuing/VBG
#   the/DT
#   (Chunk enemies/NNS)
#   of/IN
#   (Chunk freedom/NN or/CC retreat/NN)
#   from/IN
#   (Chunk our/PRP$ duties/NNS)
#   in/IN
#   the/DT
#   (Chunk hope/NN)
#   of/IN
#   an/DT
#   (Chunk easier/JJ life/NN We/PRP will/MD)
#   choose/VB
#   (Chunk to/TO)
#   build/VB
#   (Chunk our/PRP$ prosperity/NN)
#   by/IN
#   leading/VBG
#   the/DT
#   (Chunk world/NN economy/NN or/CC)
#   shut/VBN
#   (Chunk ourselves/PRP off/RP)
#   from/IN
#   (Chunk trade/NN and/CC opportunity/NN)
#   In/IN
#   a/DT
#   (Chunk complex/JJ and/CC challenging/JJ time/NN)
#   the/DT
#   (Chunk road/NN)
#   of/IN
#   (Chunk isolationism/NN and/CC protectionism/NN may/MD)
#   seem/VB
#   (Chunk broad/JJ and/CC)
#   inviting/VBG
#   (Chunk yet/RB it/PRP)
#   ends/VBZ
#   in/IN
#   (Chunk danger/NN and/CC)
#   decline/VB
#   The/DT
#   (Chunk only/JJ way/NN to/TO)
#   protect/VB
#   (Chunk our/PRP$ people/NNS)
#   the/DT
#   (Chunk only/JJ way/NN to/TO)
#   secure/VB
#   the/DT
#   (Chunk peace/NN)
#   the/DT
#   (Chunk only/JJ way/NN to/TO)
#   control/VB
#   (Chunk our/PRP$ destiny/NN)
#   is/VBZ
#   by/IN
#   (Chunk our/PRP$ leadership/NN)
#   so/IN
#   the/DT
#   (Chunk United/NNP States/NNPS)
#   of/IN
#   (Chunk America/NNP will/MD)
#   continue/VB
#   (Chunk to/TO)
#   lead/VB
#   (Chunk Applause/NNP Abroad/NNP our/PRP$ nation/NN)
#   is/VBZ
#   committed/VBN
#   (Chunk to/TO)
#   an/DT
#   (Chunk historic/JJ long/JJ term/NN goal/NN we/PRP)
#   seek/VBP
#   the/DT
#   (Chunk end/NN)
#   of/IN
#   (Chunk tyranny/NN)
#   in/IN
#   (Chunk our/PRP$ world/NN)
#   Some/DT
#   dismiss/VBP
#   that/DT
#   (Chunk goal/NN)
#   as/IN
#   (Chunk misguided/JJ idealism/NN)
#   In/IN
#   (Chunk reality/NN)
#   the/DT
#   (Chunk future/JJ security/NN)
#   of/IN
#   (Chunk America/NNP)
#   depends/VBZ
#   on/IN
#   (Chunk it/PRP)
#   On/IN
#   (Chunk September/NNP)
#   the/DT
#   (Chunk th/NN we/PRP)
#   found/VBD
#   that/IN
#   (Chunk problems/NNS)
#   originating/VBG
#   in/IN
#   a/DT
#   (Chunk
#     failed/JJ
#     and/CC
#     oppressive/JJ
#     state/NN
#     miles/NNS
#     away/RB
#     could/MD)
#   bring/VB
#   (Chunk
#     murder/NN
#     and/CC
#     destruction/NN
#     to/TO
#     our/PRP$
#     country/NN
#     Dictatorships/NNP
#     shelter/NN
#     terrorists/NNS
#     and/CC)
#   feed/VB
#   (Chunk
#     resentment/NN
#     and/CC
#     radicalism/NN
#     and/CC
#     seek/JJ
#     weapons/NNS)
#   of/IN
#   (Chunk mass/NN destruction/NN Democracies/NNP)
#   replace/VB
#   (Chunk resentment/NN)
#   with/IN
#   (Chunk hope/NN)
#   respect/VBP
#   the/DT
#   (Chunk rights/NNS)
#   of/IN
#   (Chunk
#     their/PRP$
#     citizens/NNS
#     and/CC
#     their/PRP$
#     neighbors/NNS
#     and/CC)
#   join/VB
#   the/DT
#   (Chunk fight/NN)
#   against/IN
#   (Chunk terror/NN Every/NNP step/NN)
#   toward/IN
#   (Chunk freedom/NN)
#   in/IN
#   the/DT
#   (Chunk world/NN)
#   makes/VBZ
#   (Chunk our/PRP$ country/NN)
#   safer/VBP
#   so/IN
#   (Chunk we/PRP will/MD)
#   act/VB
#   (Chunk boldly/RB)
#   in/IN
#   (Chunk freedom/NN s/NN cause/NN Applause/NNP Far/NNP)
#   from/IN
#   being/VBG
#   a/DT
#   (Chunk hopeless/NN dream/NN)
#   the/DT
#   (Chunk advance/NN)
#   of/IN
#   (Chunk freedom/NN)
#   is/VBZ
#   the/DT
#   (Chunk great/JJ story/NN)
#   of/IN
#   (Chunk our/PRP$ time/NN)
#   In/IN
#   (Chunk there/EX)
#   were/VBD
#   (Chunk about/RB two/CD dozen/NN lonely/RB)
#   democracies/VBZ
#   in/IN
#   the/DT
#   (Chunk world/NN Today/NN there/EX)
#   are/VBP
#   (Chunk And/CC we/PRP)
#   re/VBP
#   writing/VBG
#   a/DT
#   (Chunk new/JJ chapter/NN)
#   in/IN
#   the/DT
#   (Chunk story/NN)
#   of/IN
#   (Chunk self/JJ government/NN)
#   with/IN
#   (Chunk women/NNS)
#   lining/VBG
#   (Chunk up/RP to/TO)
#   vote/VB
#   in/IN
#   (Chunk Afghanistan/NNP and/CC millions/NNS)
#   of/IN
#   (Chunk Iraqis/NNP)
#   marking/VBG
#   (Chunk their/PRP$ liberty/NN)
#   with/IN
#   (Chunk purple/JJ ink/NN and/CC men/NNS and/CC women/NNS)
#   from/IN
#   (Chunk Lebanon/NNP to/TO Egypt/NNP)
#   debating/VBG
#   the/DT
#   (Chunk rights/NNS)
#   of/IN
#   (Chunk individuals/NNS and/CC)
#   the/DT
#   (Chunk necessity/NN)
#   of/IN
#   (Chunk freedom/NN)
#   At/IN
#   the/DT
#   (Chunk start/NN)
#   of/IN
#   (Chunk more/JJR)
#   than/IN
#   (Chunk half/PDT)
#   the/DT
#   (Chunk people/NNS)
#   of/IN
#   (Chunk our/PRP$ world/NN)
#   live/VBP
#   in/IN
#   (Chunk democratic/JJ nations/NNS And/CC we/PRP)
#   do/VBP
#   (Chunk not/RB)
#   forget/VB
#   the/DT
#   (Chunk other/JJ half/NN)
#   in/IN
#   (Chunk places/NNS)
#   like/IN
#   (Chunk
#     Syria/NNP
#     and/CC
#     Burma/NNP
#     Zimbabwe/NNP
#     North/NNP
#     Korea/NNP
#     and/CC
#     Iran/NNP)
#   because/IN
#   the/DT
#   (Chunk demands/NNS)
#   of/IN
#   (Chunk justice/NN and/CC)
#   the/DT
#   (Chunk peace/NN)
#   of/IN
#   this/DT
#   (Chunk world/NN)
#   require/VBP
#   (Chunk their/PRP$ freedom/NN)
#   as/IN
#   (Chunk
#     well/RB
#     Applause/NNP
#     President/NNP
#     George/NNP
#     W/NNP
#     Bush/NNP)
#   delivers/VBZ
#   (Chunk his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk
#     Capitol/NNP
#     Tuesday/NNP
#     Jan/NNP
#     White/NNP
#     House/NNP
#     photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP No/NNP one/NN can/MD)
#   deny/VB
#   the/DT
#   (Chunk success/NN)
#   of/IN
#   (Chunk freedom/NN but/CC)
#   some/DT
#   (Chunk men/NNS)
#   rage/VB
#   (Chunk and/CC)
#   fight/VB
#   against/IN
#   (Chunk it/PRP And/CC one/CD)
#   of/IN
#   the/DT
#   (Chunk main/JJ sources/NNS)
#   of/IN
#   (Chunk reaction/NN and/CC opposition/NN)
#   is/VBZ
#   (Chunk radical/JJ Islam/NNP)
#   the/DT
#   (Chunk perversion/NN)
#   by/IN
#   a/DT
#   (Chunk few/JJ)
#   of/IN
#   a/DT
#   (Chunk noble/JJ faith/NN)
#   into/IN
#   an/DT
#   (Chunk ideology/NN)
#   of/IN
#   (Chunk terror/NN and/CC death/NN Terrorists/NNS)
#   like/IN
#   (Chunk bin/NN Laden/NNP)
#   are/VBP
#   (Chunk serious/JJ)
#   about/IN
#   (Chunk mass/NN murder/NN and/CC)
#   all/DT
#   of/IN
#   (Chunk us/PRP must/MD)
#   take/VB
#   (Chunk their/PRP$ declared/JJ intentions/NNS seriously/RB They/PRP)
#   seek/VBP
#   (Chunk to/TO)
#   impose/VB
#   a/DT
#   (Chunk heartless/NN system/NN)
#   of/IN
#   (Chunk totalitarian/JJ control/NN)
#   throughout/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP and/CC arm/NN themselves/PRP)
#   with/IN
#   (Chunk weapons/NNS)
#   of/IN
#   (Chunk mass/NN)
#   murder/VBP
#   (Chunk Their/PRP$ aim/NN)
#   is/VBZ
#   (Chunk to/TO)
#   seize/VB
#   (Chunk power/NN)
#   in/IN
#   (Chunk Iraq/NNP and/CC)
#   use/VB
#   (Chunk it/PRP)
#   as/IN
#   a/DT
#   (Chunk safe/JJ haven/NN to/TO)
#   launch/VB
#   (Chunk attacks/NNS)
#   against/IN
#   (Chunk America/NNP and/CC)
#   the/DT
#   (Chunk world/NN)
#   Lacking/VBG
#   the/DT
#   (Chunk military/JJ strength/NN to/TO)
#   challenge/VB
#   (Chunk us/PRP directly/RB)
#   the/DT
#   (Chunk terrorists/NNS)
#   have/VBP
#   chosen/VBN
#   the/DT
#   (Chunk weapon/NN)
#   of/IN
#   (Chunk fear/NN When/WRB they/PRP)
#   murder/VBP
#   (Chunk children/NNS)
#   at/IN
#   a/DT
#   (Chunk school/NN)
#   in/IN
#   (Chunk Beslan/NNP or/CC)
#   blow/VB
#   (Chunk up/RP commuters/NNS)
#   in/IN
#   (Chunk London/NNP or/CC)
#   behead/VB
#   a/DT
#   (Chunk bound/NN)
#   captive/VBZ
#   the/DT
#   (Chunk terrorists/NNS)
#   hope/VBP
#   these/DT
#   (Chunk horrors/NNS will/MD)
#   break/VB
#   (Chunk our/PRP$ will/MD)
#   allowing/VBG
#   the/DT
#   (Chunk violent/NN to/TO)
#   inherit/VB
#   the/DT
#   (Chunk Earth/NN But/CC they/PRP)
#   have/VBP
#   miscalculated/VBN
#   (Chunk We/PRP)
#   love/VBP
#   (Chunk our/PRP$ freedom/NN and/CC we/PRP will/MD)
#   fight/VB
#   (Chunk to/TO)
#   keep/VB
#   (Chunk it/PRP Applause/NNP)
#   In/IN
#   a/DT
#   (Chunk time/NN)
#   of/IN
#   testing/VBG
#   (Chunk we/PRP can/MD not/RB)
#   find/VB
#   (Chunk security/NN)
#   by/IN
#   abandoning/VBG
#   (Chunk our/PRP$ commitments/NNS and/CC)
#   retreating/VBG
#   within/IN
#   (Chunk our/PRP$ borders/NNS)
#   If/IN
#   (Chunk we/PRP)
#   were/VBD
#   (Chunk to/TO)
#   leave/VB
#   these/DT
#   (Chunk vicious/JJ attackers/NNS alone/RB they/PRP would/MD not/RB)
#   leave/VB
#   (Chunk us/PRP alone/RB They/PRP would/MD simply/RB)
#   move/VB
#   the/DT
#   (Chunk battlefield/NN to/TO our/PRP$ own/JJ shores/NNS There/EX)
#   is/VBZ
#   no/DT
#   (Chunk peace/NN)
#   in/IN
#   (Chunk retreat/NN And/CC there/EX)
#   is/VBZ
#   no/DT
#   (Chunk honor/NN)
#   in/IN
#   (Chunk retreat/NN)
#   By/IN
#   allowing/VBG
#   (Chunk radical/JJ Islam/NNP to/TO)
#   work/VB
#   (Chunk its/PRP$ will/MD)
#   by/IN
#   leaving/VBG
#   an/DT
#   (Chunk assaulted/JJ world/NN to/TO)
#   fend/VB
#   for/IN
#   (Chunk itself/PRP we/PRP would/MD)
#   signal/VB
#   (Chunk to/TO all/PDT)
#   that/IN
#   (Chunk we/PRP)
#   no/DT
#   (Chunk longer/RBR)
#   believe/VBP
#   in/IN
#   (Chunk our/PRP$ own/JJ ideals/NNS or/CC even/RB)
#   in/IN
#   (Chunk
#     our/PRP$
#     own/JJ
#     courage/NN
#     But/CC
#     our/PRP$
#     enemies/NNS
#     and/CC
#     our/PRP$
#     friends/NNS
#     can/MD)
#   be/VB
#   (Chunk certain/JJ)
#   The/DT
#   (Chunk United/NNP States/NNPS will/MD not/RB)
#   retreat/VB
#   from/IN
#   the/DT
#   (Chunk world/NN and/CC we/PRP will/MD never/RB)
#   surrender/VB
#   (Chunk to/TO)
#   evil/VB
#   (Chunk Applause/NNP America/NNP)
#   rejects/VBZ
#   the/DT
#   (Chunk false/JJ comfort/NN)
#   of/IN
#   (Chunk isolationism/NN We/PRP)
#   are/VBP
#   the/DT
#   (Chunk nation/NN)
#   that/IN
#   saved/VBD
#   (Chunk liberty/NN)
#   in/IN
#   (Chunk Europe/NNP and/CC)
#   liberated/VBN
#   (Chunk death/NN camps/NNS and/CC)
#   helped/VBD
#   raise/VB
#   (Chunk up/RP democracies/NNS and/CC)
#   faced/VBD
#   down/IN
#   an/DT
#   (Chunk evil/JJ empire/NN Once/RB again/RB we/PRP)
#   accept/VBP
#   the/DT
#   (Chunk call/NN)
#   of/IN
#   (Chunk history/NN to/TO)
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   (Chunk and/CC)
#   move/VB
#   this/DT
#   (Chunk world/NN)
#   toward/IN
#   (Chunk peace/NN We/PRP)
#   remain/VBP
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   against/IN
#   (Chunk terror/NN networks/NNS We/PRP)
#   have/VBP
#   killed/VBN
#   (Chunk or/CC)
#   captured/VBN
#   (Chunk many/JJ)
#   of/IN
#   (Chunk their/PRP$ leaders/NNS and/CC)
#   for/IN
#   the/DT
#   (Chunk others/NNS their/PRP$ day/NN will/MD)
#   come/VB
#   (Chunk President/NNP George/NNP W/NNP Bush/NNP)
#   greets/VBZ
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   after/IN
#   (Chunk his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (Chunk
#     Capitol/NNP
#     Tuesday/NNP
#     Jan/NNP
#     White/NNP
#     House/NNP
#     photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP We/PRP)
#   remain/VBP
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   in/IN
#   (Chunk Afghanistan/NNP where/WRB)
#   a/DT
#   (Chunk fine/JJ President/NNP and/CC)
#   a/DT
#   (Chunk National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   (Chunk terror/NN)
#   while/IN
#   building/VBG
#   the/DT
#   (Chunk institutions/NNS)
#   of/IN
#   a/DT
#   (Chunk new/JJ democracy/NN We/PRP)
#   re/VBP
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   in/IN
#   (Chunk Iraq/NNP)
#   with/IN
#   a/DT
#   (Chunk clear/JJ plan/NN)
#   for/IN
#   (Chunk victory/NN First/NNP we/PRP)
#   re/VBP
#   helping/VBG
#   (Chunk Iraqis/NNP)
#   build/VB
#   an/DT
#   (Chunk inclusive/JJ government/NN)
#   so/IN
#   that/IN
#   (Chunk old/JJ resentments/NNS will/MD)
#   be/VB
#   eased/VBN
#   (Chunk and/CC)
#   the/DT
#   (Chunk insurgency/NN will/MD)
#   be/VB
#   marginalized/VBN
#   (Chunk Second/NNP we/PRP)
#   re/VBP
#   continuing/VBG
#   (Chunk reconstruction/NN efforts/NNS and/CC)
#   helping/VBG
#   the/DT
#   (Chunk Iraqi/NNP government/NN to/TO)
#   fight/VB
#   (Chunk corruption/NN and/CC)
#   build/VB
#   a/DT
#   (Chunk modern/JJ economy/NN so/RB)
#   all/DT
#   (Chunk Iraqis/NNP can/MD)
#   experience/VB
#   the/DT
#   (Chunk benefits/NNS)
#   of/IN
#   (Chunk freedom/NN And/CC third/JJ we/PRP)
#   re/VBP
#   striking/VBG
#   (Chunk terrorist/JJ targets/NNS)
#   while/IN
#   (Chunk we/PRP)
#   train/VBP
#   (Chunk Iraqi/JJ forces/NNS that/WDT)
#   are/VBP
#   (Chunk increasingly/RB capable/JJ)
#   of/IN
#   defeating/VBG
#   the/DT
#   (Chunk enemy/NN Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   (Chunk their/PRP$ courage/NN)
#   every/DT
#   (Chunk day/NN and/CC we/PRP)
#   are/VBP
#   (Chunk proud/JJ to/TO)
#   be/VB
#   (Chunk their/PRP$ allies/NNS)
#   in/IN
#   the/DT
#   (Chunk cause/NN)
#   of/IN
#   (Chunk freedom/NN Applause/NNP Our/PRP$ work/NN)
#   in/IN
#   (Chunk Iraq/NNP)
#   is/VBZ
#   (Chunk difficult/JJ)
#   because/IN
#   (Chunk our/PRP$ enemy/NN)
#   is/VBZ
#   (Chunk brutal/JJ But/CC)
#   that/DT
#   (Chunk brutality/NN)
#   has/VBZ
#   (Chunk not/RB)
#   stopped/VBN
#   the/DT
#   (Chunk dramatic/JJ progress/NN)
#   of/IN
#   a/DT
#   (Chunk new/JJ democracy/NN)
#   In/IN
#   (Chunk less/JJR)
#   than/IN
#   (Chunk three/CD years/NNS)
#   the/DT
#   (Chunk nation/NN)
#   has/VBZ
#   gone/VBN
#   from/IN
#   (Chunk dictatorship/NN to/TO liberation/NN to/TO)
#   sovereignty/VB
#   (Chunk to/TO)
#   a/DT
#   (Chunk constitution/NN to/TO national/JJ elections/NNS)
#   At/IN
#   the/DT
#   (Chunk same/JJ time/NN our/PRP$ coalition/NN)
#   has/VBZ
#   been/VBN
#   relentless/VBN
#   in/IN
#   shutting/VBG
#   (Chunk off/RP terrorist/JJ infiltration/NN)
#   clearing/VBG
#   (Chunk out/RP insurgent/JJ strongholds/NNS and/CC)
#   turning/VBG
#   (Chunk
#     over/RP
#     territory/NN
#     to/TO
#     Iraqi/NNP
#     security/NN
#     forces/NNS
#     I/PRP)
#   am/VBP
#   (Chunk confident/JJ)
#   in/IN
#   (Chunk our/PRP$ plan/NN)
#   for/IN
#   (Chunk victory/NN I/PRP)
#   am/VBP
#   (Chunk confident/JJ)
#   in/IN
#   the/DT
#   (Chunk will/MD)
#   of/IN
#   the/DT
#   (Chunk Iraqi/NNP people/NNS I/PRP)
#   am/VBP
#   (Chunk confident/JJ)
#   in/IN
#   the/DT
#   (Chunk skill/NN and/CC spirit/NN)
#   of/IN
#   (Chunk our/PRP$ military/JJ Fellow/NNP citizens/NNS we/PRP)
#   are/VBP
#   in/IN
#   this/DT
#   (Chunk fight/NN to/TO)
#   win/VB
#   (Chunk and/CC we/PRP)
#   are/VBP
#   winning/VBG
#   Applause/IN
#   The/DT
#   (Chunk road/NN)
#   of/IN
#   (Chunk victory/NN)
#   is/VBZ
#   the/DT
#   (Chunk road/NN that/WDT will/MD)
#   take/VB
#   (Chunk our/PRP$ troops/NNS home/NN)
#   As/IN
#   (Chunk we/PRP)
#   make/VBP
#   (Chunk progress/NN)
#   on/IN
#   the/DT
#   (Chunk ground/NN and/CC Iraqi/NNP forces/NNS increasingly/RB)
#   take/VBP
#   the/DT
#   (Chunk lead/NN we/PRP should/MD)
#   be/VB
#   (Chunk able/JJ to/TO further/JJ)
#   decrease/VB
#   (Chunk our/PRP$ troop/NN levels/NNS but/CC)
#   those/DT
#   (Chunk decisions/NNS will/MD)
#   be/VB
#   made/VBN
#   by/IN
#   (Chunk our/PRP$ military/JJ commanders/NNS not/RB)
#   by/IN
#   (Chunk politicians/NNS)
#   in/IN
#   (Chunk
#     Washington/NNP
#     D/NNP
#     C/NNP
#     Applause/NNP
#     Our/PRP$
#     coalition/NN)
#   has/VBZ
#   learned/VBN
#   from/IN
#   (Chunk our/PRP$ experience/NN)
#   in/IN
#   (Chunk Iraq/NNP We/PRP)
#   ve/VBP
#   adjusted/VBN
#   (Chunk our/PRP$ military/JJ tactics/NNS and/CC)
#   changed/VBD
#   (Chunk our/PRP$ approach/NN to/TO)
#   reconstruction/VB
#   Along/IN
#   the/DT
#   (Chunk way/NN we/PRP)
#   have/VBP
#   benefitted/VBN
#   from/IN
#   (Chunk responsible/JJ criticism/NN and/CC counsel/NN)
#   offered/VBN
#   by/IN
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   (Chunk parties/NNS)
#   In/IN
#   the/DT
#   coming/VBG
#   (Chunk year/NN I/PRP will/MD)
#   continue/VB
#   (Chunk to/TO)
#   reach/VB
#   (Chunk out/RP and/CC)
#   seek/VB
#   (Chunk your/PRP$ good/JJ advice/NN Yet/RB there/EX)
#   is/VBZ
#   a/DT
#   (Chunk difference/NN)
#   between/IN
#   (Chunk responsible/JJ criticism/NN that/WDT)
#   aims/VBZ
#   for/IN
#   (Chunk success/NN and/CC defeatism/NN that/WDT)
#   refuses/VBZ
#   (Chunk to/TO)
#   acknowledge/VB
#   (Chunk
#     anything/NN
#     but/CC
#     failure/NN
#     Applause/NNP
#     Hindsight/NNP
#     alone/RB)
#   is/VBZ
#   (Chunk not/RB wisdom/JJ and/CC second/JJ guessing/NN)
#   is/VBZ
#   (Chunk not/RB)
#   a/DT
#   (Chunk strategy/NN Applause/NNP)
#   With/IN
#   (Chunk so/RB much/JJ)
#   in/IN
#   the/DT
#   (Chunk balance/NN)
#   those/DT
#   of/IN
#   (Chunk us/PRP)
#   in/IN
#   (Chunk public/JJ office/NN)
#   have/VBP
#   a/DT
#   (Chunk duty/NN to/TO)
#   speak/VB
#   with/IN
#   (Chunk candor/NN A/NNP sudden/JJ withdrawal/NN)
#   of/IN
#   (Chunk our/PRP$ forces/NNS)
#   from/IN
#   (Chunk Iraq/NNP would/MD)
#   abandon/VB
#   (Chunk
#     our/PRP$
#     Iraqi/NNP
#     allies/NNS
#     to/TO
#     death/NN
#     and/CC
#     prison/NN
#     would/MD)
#   put/VB
#   (Chunk men/NNS)
#   like/IN
#   (Chunk bin/NN Laden/NNP and/CC Zarqawi/NNP)
#   in/IN
#   (Chunk charge/NN)
#   of/IN
#   a/DT
#   (Chunk strategic/JJ country/NN and/CC)
#   show/VBP
#   that/IN
#   a/DT
#   (Chunk pledge/NN)
#   from/IN
#   (Chunk America/NNP)
#   means/VBZ
#   (Chunk little/JJ Members/NNS)
#   of/IN
#   (Chunk Congress/NNP however/RB we/PRP)
#   feel/VBP
#   about/IN
#   the/DT
#   (Chunk decisions/NNS and/CC debates/NNS)
#   of/IN
#   the/DT
#   (Chunk past/JJ our/PRP$ nation/NN)
#   has/VBZ
#   (Chunk only/RB one/CD option/NN We/PRP must/MD)
#   keep/VB
#   (Chunk our/PRP$ word/NN)
#   defeat/VB
#   (Chunk our/PRP$ enemies/NNS and/CC)
#   stand/VBP
#   behind/IN
#   the/DT
#   (Chunk American/JJ military/NN)
#   in/IN
#   this/DT
#   (Chunk vital/JJ mission/NN Applause/NNP Laura/NNP Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/IN
#   (Chunk she/PRP)
#   is/VBZ
#   introduced/VBN
#   (Chunk Tuesday/NNP)
#   evening/VBG
#   (Chunk Jan/NNP)
#   during/IN
#   the/DT
#   (Chunk State/NNP)
#   of/IN
#   the/DT
#   (Chunk Union/NNP Address/NNP)
#   at/IN
#   (Chunk United/NNP States/NNPS Capitol/NNP)
#   in/IN
#   (Chunk Washington/NNP White/NNP House/NNP photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP Our/PRP$ men/NNS and/CC women/NNS)
#   in/IN
#   (Chunk uniform/JJ)
#   are/VBP
#   making/VBG
#   (Chunk sacrifices/NNS and/CC)
#   showing/VBG
#   a/DT
#   (Chunk sense/NN)
#   of/IN
#   (Chunk duty/NN stronger/JJR)
#   than/IN
#   all/DT
#   fear/VBP
#   (Chunk They/PRP)
#   know/VBP
#   (Chunk what/WP it/PRP)
#   s/VBZ
#   like/IN
#   (Chunk to/TO)
#   fight/VB
#   (Chunk house/NN to/TO house/NN)
#   in/IN
#   a/DT
#   (Chunk maze/NN)
#   of/IN
#   (Chunk streets/NNS to/TO)
#   wear/VB
#   (Chunk heavy/JJ gear/NN)
#   in/IN
#   the/DT
#   (Chunk desert/NN heat/NN to/TO)
#   see/VB
#   a/DT
#   (Chunk comrade/NN)
#   killed/VBN
#   by/IN
#   a/DT
#   (Chunk roadside/NN bomb/NN And/CC)
#   those/DT
#   (Chunk who/WP)
#   know/VBP
#   the/DT
#   (Chunk costs/NNS also/RB)
#   know/VBP
#   the/DT
#   (Chunk
#     stakes/NNS
#     Marine/NNP
#     Staff/NNP
#     Sergeant/NNP
#     Dan/NNP
#     Clay/NNP)
#   was/VBD
#   killed/VBN
#   (Chunk last/JJ month/NN)
#   fighting/VBG
#   in/IN
#   (Chunk Fallujah/NNP He/PRP)
#   left/VBD
#   (Chunk behind/RP)
#   a/DT
#   (Chunk
#     letter/NN
#     to/TO
#     his/PRP$
#     family/NN
#     but/CC
#     his/PRP$
#     words/NNS
#     could/MD
#     just/RB
#     as/RB
#     well/RB)
#   be/VB
#   addressed/VBN
#   (Chunk to/TO)
#   every/DT
#   (Chunk American/NNP Here/RB)
#   is/VBZ
#   (Chunk what/WP Dan/NNP)
#   wrote/VBD
#   (Chunk I/PRP)
#   know/VBP
#   (Chunk what/WP honor/NN)
#   is/VBZ
#   (Chunk It/PRP)
#   has/VBZ
#   been/VBN
#   an/DT
#   (Chunk honor/NN to/TO)
#   protect/VB
#   (Chunk and/CC)
#   serve/VB
#   all/DT
#   of/IN
#   (Chunk you/PRP I/PRP)
#   faced/VBD
#   (Chunk death/NN)
#   with/IN
#   the/DT
#   (Chunk secure/NN knowledge/NN)
#   that/IN
#   (Chunk you/PRP would/MD not/RB)
#   have/VB
#   (Chunk to/TO Never/NNP falter/NN Don/NNP t/NN hesitate/NN to/TO)
#   honor/VB
#   (Chunk and/CC)
#   support/VB
#   those/DT
#   of/IN
#   (Chunk us/PRP who/WP)
#   have/VBP
#   the/DT
#   (Chunk honor/NN)
#   of/IN
#   protecting/VBG
#   that/DT
#   (Chunk which/WDT)
#   is/VBZ
#   worth/IN
#   protecting/VBG
#   (Chunk Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
#   s/VBD
#   (Chunk
#     wife/NN
#     Lisa/NNP
#     and/CC
#     his/PRP$
#     mom/NN
#     and/CC
#     dad/NN
#     Sara/NNP
#     Jo/NNP
#     and/CC
#     Bud/NNP)
#   are/VBP
#   with/IN
#   (Chunk us/PRP)
#   this/DT
#   evening/VBG
#   (Chunk Welcome/NNP Applause/NNP Our/PRP$ nation/NN)
#   is/VBZ
#   (Chunk grateful/JJ to/TO)
#   the/DT
#   fallen/VBN
#   (Chunk who/WP)
#   live/VBP
#   in/IN
#   the/DT
#   (Chunk memory/NN)
#   of/IN
#   (Chunk our/PRP$ country/NN We/PRP)
#   re/VBP
#   (Chunk grateful/JJ to/TO)
#   all/DT
#   (Chunk who/WP)
#   volunteer/VBP
#   (Chunk to/TO)
#   wear/VB
#   (Chunk our/PRP$ nation/NN s/NN uniform/NN and/CC)
#   as/IN
#   (Chunk we/PRP)
#   honor/VBP
#   (Chunk our/PRP$ brave/NN troops/NNS)
#   let/VB
#   (Chunk us/PRP never/RB)
#   forget/VBP
#   the/DT
#   (Chunk sacrifices/NNS)
#   of/IN
#   (Chunk America/NNP)
#   s/VBP
#   (Chunk military/JJ families/NNS)
#   Applause/IN
#   (Chunk Our/PRP$ offensive/JJ)
#   against/IN
#   (Chunk terror/NN)
#   involves/VBZ
#   (Chunk more/JJR)
#   than/IN
#   (Chunk military/JJ action/NN Ultimately/RB)
#   the/DT
#   (Chunk only/JJ way/NN to/TO)
#   defeat/VB
#   the/DT
#   (Chunk terrorists/NNS)
#   is/VBZ
#   (Chunk to/TO)
#   defeat/VB
#   (Chunk their/PRP$ dark/JJ vision/NN)
#   of/IN
#   hatred/VBN
#   (Chunk and/CC)
#   fear/VBN
#   by/IN
#   offering/VBG
#   the/DT
#   (Chunk hopeful/JJ alternative/NN)
#   of/IN
#   (Chunk political/JJ freedom/NN and/CC peaceful/JJ change/NN)
#   So/IN
#   the/DT
#   (Chunk United/NNP States/NNPS)
#   of/IN
#   (Chunk America/NNP supports/NNS democratic/JJ reform/NN)
#   across/IN
#   the/DT
#   (Chunk broader/JJR Middle/NNP East/NNP Elections/NNS)
#   are/VBP
#   (Chunk vital/JJ but/CC they/PRP)
#   are/VBP
#   (Chunk only/RB)
#   the/DT
#   (Chunk beginning/NN)
#   Raising/VBG
#   (Chunk up/RP)
#   a/DT
#   (Chunk democracy/NN)
#   requires/VBZ
#   the/DT
#   (Chunk rule/NN)
#   of/IN
#   (Chunk law/NN and/CC protection/NN)
#   of/IN
#   (Chunk
#     minorities/NNS
#     and/CC
#     strong/JJ
#     accountable/JJ
#     institutions/NNS)
#   that/IN
#   (Chunk last/JJ longer/JJR)
#   than/IN
#   a/DT
#   (Chunk single/JJ vote/NN)
#   The/DT
#   (Chunk great/JJ people/NNS)
#   of/IN
#   (Chunk Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   (Chunk
#     multi/NN
#     party/NN
#     presidential/JJ
#     election/NN
#     and/CC
#     now/RB
#     their/PRP$
#     government/NN
#     should/MD)
#   open/VB
#   (Chunk paths/NNS)
#   of/IN
#   (Chunk peaceful/JJ opposition/NN that/WDT will/MD)
#   reduce/VB
#   the/DT
#   (Chunk appeal/NN)
#   of/IN
#   (Chunk radicalism/NN)
#   The/DT
#   (Chunk Palestinian/JJ people/NNS)
#   have/VBP
#   voted/VBN
#   in/IN
#   (Chunk elections/NNS And/CC now/RB)
#   the/DT
#   (Chunk leaders/NNS)
#   of/IN
#   (Chunk Hamas/NNP must/MD)
#   recognize/VB
#   (Chunk Israel/NNP disarm/NN reject/NN terrorism/NN and/CC work/NN)
#   for/IN
#   lasting/VBG
#   (Chunk peace/NN Applause/NNP Saudi/NNP Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   (Chunk first/JJ steps/NNS)
#   of/IN
#   (Chunk reform/NN now/RB it/PRP can/MD)
#   offer/VB
#   (Chunk its/PRP$ people/NNS)
#   a/DT
#   (Chunk better/JJR future/NN)
#   by/IN
#   pressing/VBG
#   (Chunk forward/RB)
#   with/IN
#   those/DT
#   (Chunk efforts/NNS Democracies/NNPS)
#   in/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP will/MD not/RB)
#   look/VB
#   like/IN
#   (Chunk our/PRP$ own/JJ)
#   because/IN
#   (Chunk they/PRP will/MD)
#   reflect/VB
#   the/DT
#   (Chunk traditions/NNS)
#   of/IN
#   (Chunk their/PRP$ own/JJ citizens/NNS Yet/NNP liberty/NN)
#   is/VBZ
#   the/DT
#   (Chunk future/NN)
#   of/IN
#   every/DT
#   (Chunk nation/NN)
#   in/IN
#   the/DT
#   (Chunk Middle/NNP East/NNP)
#   because/IN
#   (Chunk liberty/NN)
#   is/VBZ
#   the/DT
#   (Chunk right/NN and/CC hope/NN)
#   of/IN
#   all/DT
#   (Chunk
#     humanity/NN
#     Applause/NNP
#     President/NNP
#     George/NNP
#     W/NNP
#     Bush/NNP)
#   waves/VBZ
#   toward/IN
#   the/DT
#   (Chunk upper/JJ visitors/NNS gallery/NN)
#   of/IN
#   the/DT
#   (Chunk House/NNP Chamber/NNP)
#   following/VBG
#   (Chunk his/PRP$ State/NN)
#   of/IN
#   the/DT
#   (Chunk Union/NNP remarks/NNS Tuesday/NNP Jan/NNP)
#   at/IN
#   the/DT
#   (Chunk
#     United/NNP
#     States/NNPS
#     Capitol/NNP
#     White/NNP
#     House/NNP
#     photo/NN)
#   by/IN
#   (Chunk Eric/NNP Draper/NNP)
#   The/DT
#   (Chunk same/JJ)
#   is/VBZ
#   (Chunk true/JJ)
#   of/IN
#   (Chunk Iran/NNP)
#   a/DT
#   (Chunk nation/NN now/RB)
#   held/VBN
#   (Chunk hostage/NN)
#   by/IN
#   a/DT
#   (Chunk small/JJ clerical/JJ elite/NN that/WDT)
#   is/VBZ
#   isolating/VBG
#   (Chunk and/CC)
#   repressing/VBG
#   (Chunk its/PRP$ people/NNS)
#   The/DT
#   (Chunk regime/NN)
#   in/IN
#   that/DT
#   (Chunk country/NN sponsors/NNS terrorists/NNS)
#   in/IN
#   the/DT
#   (Chunk Palestinian/JJ territories/NNS and/CC)
#   in/IN
#   (Chunk Lebanon/NNP and/CC)
#   that/DT
#   (Chunk must/MD)
#   come/VB
#   (Chunk to/TO)
#   an/DT
#   (Chunk end/NN)
#   Applause/IN
#   The/DT
#   (Chunk Iranian/JJ government/NN)
#   is/VBZ
#   defying/VBG
#   the/DT
#   (Chunk world/NN)
#   with/IN
#   (Chunk its/PRP$ nuclear/JJ ambitions/NNS and/CC)
#   the/DT
#   (Chunk nations/NNS)
#   of/IN
#   the/DT
#   (Chunk world/NN must/MD not/RB)
#   permit/VB
#   the/DT
#   (Chunk Iranian/JJ regime/NN to/TO)
#   gain/VB
#   (Chunk nuclear/JJ weapons/NNS)
#   Applause/VBP
#   (Chunk America/NNP will/MD)
#   continue/VB
#   (Chunk to/TO)
#   rally/VB
#   the/DT
#   (Chunk world/NN to/TO)
#   confront/VB
#   these/DT
#   (Chunk threats/NNS Tonight/NNP)
#   let/VB
#   (Chunk me/PRP)
#   speak/VB
#   (Chunk directly/RB to/TO)
#   the/DT
#   (Chunk citizens/NNS)
#   of/IN
#   (Chunk Iran/NNP America/NNP)
#   respects/VBZ
#   (Chunk you/PRP and/CC we/PRP)
#   respect/VBP
#   (Chunk your/PRP$ country/NN We/PRP)
#   respect/VBP
#   (Chunk your/PRP$ right/NN to/TO)
#   choose/VB
#   (Chunk your/PRP$ own/JJ future/NN and/CC)
#   win/VB
#   (Chunk your/PRP$ own/JJ freedom/NN And/CC our/PRP$ nation/NN)
#   hopes/VBZ
#   (Chunk one/CD day/NN to/TO)
#   be/VB
#   the/DT
#   (Chunk closest/JJS)
#   of/IN
#   (Chunk friends/NNS)
#   with/IN
#   a/DT
#   (Chunk free/JJ and/CC democratic/JJ Iran/NNP Applause/NNP To/TO)
#   overcome/VB
#   (Chunk dangers/NNS)
#   in/IN
#   (Chunk our/PRP$ world/NN we/PRP must/MD also/RB)
#   take/VB
#   the/DT
#   (Chunk offensive/JJ)
#   by/IN
#   encouraging/VBG
#   (Chunk economic/JJ progress/NN and/CC)
#   fighting/VBG
#   (Chunk disease/NN and/CC)
#   spreading/VBG
#   (Chunk hope/NN)
#   in/IN
#   (Chunk
#     hopeless/JJ
#     lands/NNS
#     Isolationism/NNP
#     would/MD
#     not/RB
#     only/RB)
#   tie/VB
#   (Chunk our/PRP$ hands/NNS)
#   in/IN
#   fighting/VBG
#   (Chunk enemies/NNS it/PRP would/MD)
#   keep/VB
#   (Chunk us/PRP)
#   from/IN
#   helping/VBG
#   (Chunk our/PRP$ friends/NNS)
#   in/IN
#   (Chunk desperate/JJ need/NN We/PRP)
#   show/VBP
#   (Chunk compassion/JJ abroad/RB)
#   because/IN
#   (Chunk Americans/NNPS)
#   believe/VBP
#   in/IN
#   the/DT
#   (Chunk God/NNP)
#   given/VBN
#   (Chunk dignity/NN and/CC worth/NN)
#   of/IN
#   a/DT
#   (Chunk villager/NN)
#   with/IN
#   (Chunk HIV/NNP AIDS/NNP or/CC)
#   an/DT
#   (Chunk infant/NN)
#   with/IN
#   (Chunk malaria/NNS or/CC)
#   a/DT
#   (Chunk refugee/JJ fleeing/NN genocide/NN or/CC)
#   a/DT
#   (Chunk young/JJ girl/NN)
#   sold/VBN
#   into/IN
#   (Chunk slavery/NN We/PRP also/RB)
#   show/VBP
#   (Chunk compassion/NN abroad/RB)
#   because/IN
#   (Chunk regions/NNS)
#   overwhelmed/VBN
#   by/IN
#   (Chunk poverty/NN corruption/NN and/CC despair/NN)
#   are/VBP
#   (Chunk sources/NNS)
#   of/IN
#   (Chunk terrorism/NN and/CC)
#   organized/VBN
#   (Chunk crime/NN and/CC human/JJ trafficking/NN and/CC)
#   the/DT
#   (Chunk drug/NN trade/NN)
#   In/IN
#   (Chunk recent/JJ years/NNS you/PRP and/CC I/PRP)
#   have/VBP
#   taken/VBN
#   (Chunk unprecedented/JJ action/NN to/TO)
#   fight/VB
#   (Chunk AIDS/NNP and/CC malaria/NNS)
#   expand/VBP
#   the/DT
#   (Chunk education/NN)
#   of/IN
#   (Chunk girls/NNS and/CC reward/JJ)
#   developing/VBG
#   (Chunk nations/NNS that/WDT)
#   are/VBP
#   moving/VBG
#   (Chunk forward/RB)
#   with/IN
#   (Chunk economic/JJ and/CC political/JJ reform/NN)
#   For/IN
#   (Chunk people/NNS everywhere/RB)
#   the/DT
#   (Chunk United/NNP States/NNPS)
#   is/VBZ
#   a/DT
#   (Chunk partner/NN)
#   for/IN
#   a/DT
#   (Chunk better/JJR life/NN Short/NNP)
#   changing/VBG
#   these/DT
#   (Chunk efforts/NNS would/MD)
#   increase/VB
#   the/DT
#   (Chunk suffering/NN and/CC chaos/NN)
#   of/IN
#   (Chunk our/PRP$ world/NN)
#   undercut/IN
#   (Chunk our/PRP$ long/JJ term/NN security/NN and/CC)
#   dull/VB
#   the/DT
#   (Chunk conscience/NN)
#   of/IN
#   (Chunk our/PRP$ country/NN I/PRP)
#   urge/VBP
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP to/TO)
#   serve/VB
#   the/DT
#   (Chunk interests/NNS)
#   of/IN
#   (Chunk America/NNP)
#   by/IN
#   showing/VBG
#   the/DT
#   (Chunk compassion/NN)
#   of/IN
#   (Chunk America/NNP Our/PRP$ country/NN must/MD also/RB)
#   remain/VB
#   on/IN
#   the/DT
#   (Chunk offensive/JJ)
#   against/IN
#   (Chunk terrorism/NN here/RB)
#   at/IN
#   (Chunk home/NN)
#   The/DT
#   (Chunk enemy/NN)
#   has/VBZ
#   (Chunk not/RB)
#   lost/VBN
#   the/DT
#   (Chunk desire/NN or/CC capability/NN to/TO)
#   attack/VB
#   (Chunk us/PRP Fortunately/RB)
#   this/DT
#   (Chunk nation/NN)
#   has/VBZ
#   superb/VBN
#   (Chunk professionals/NNS)
#   in/IN
#   (Chunk law/NN enforcement/NN intelligence/NN)
#   the/DT
#   (Chunk military/JJ and/CC homeland/JJ security/NN)
#   These/DT
#   (Chunk men/NNS and/CC women/NNS)
#   are/VBP
#   dedicating/VBG
#   (Chunk their/PRP$ lives/NNS)
#   protecting/VBG
#   (Chunk us/PRP)
#   all/DT
#   (Chunk and/CC they/PRP)
#   deserve/VBP
#   (Chunk our/PRP$ support/NN and/CC our/PRP$ thanks/NNS)
#   Applause/IN
#   (Chunk They/PRP also/RB)
#   deserve/VBP
#   the/DT
#   (Chunk same/JJ tools/NNS they/PRP already/RB)
#   use/VBP
#   (Chunk to/TO)
#   fight/VB
#   (Chunk drug/NN trafficking/NN and/CC)
#   organized/VBN
#   (Chunk crime/NN)
#   so/IN
#   (Chunk I/PRP)
#   ask/VBP
#   (Chunk you/PRP to/TO)
#   reauthorize/VB
#   the/DT
#   (Chunk Patriot/NNP Act/NNP)
#   Applause/IN
#   (Chunk It/PRP)
#   is/VBZ
#   said/VBD
#   that/IN
#   (Chunk prior/JJ to/TO)
#   the/DT
#   (Chunk attacks/NNS)
#   of/IN
#   (Chunk September/NNP)
#   the/DT
#   (Chunk th/JJ our/PRP$ government/NN)
#   failed/VBD
#   (Chunk to/TO)
#   connect/VB
#   the/DT
#   (Chunk dots/NNS)
#   of/IN
#   the/DT
#   (Chunk conspiracy/NN We/PRP now/RB)
#   know/VBP
#   that/IN
#   (Chunk two/CD)
#   of/IN
#   the/DT
#   (Chunk hijackers/NNS)
#   in/IN
#   the/DT
#   (Chunk United/NNP States/NNPS)
#   placed/VBD
#   (Chunk telephone/NN calls/NNS to/TO)
#   al/VB
#   (Chunk Qaeda/NNP operatives/PRP overseas/RB But/CC we/PRP)
#   did/VBD
#   (Chunk not/RB)
#   know/VB
#   about/IN
#   (Chunk their/PRP$ plans/NNS)
#   until/IN
#   (Chunk it/PRP)
#   was/VBD
#   (Chunk too/RB late/RB So/RB to/TO)
#   prevent/VB
#   another/DT
#   (Chunk attack/NN)
#   based/VBN
#   on/IN
#   (Chunk authority/NN)
#   given/VBN
#   (Chunk to/TO me/PRP)
#   by/IN
#   the/DT
#   (Chunk Constitution/NNP and/CC)
#   by/IN
#   (Chunk statute/NN I/PRP)
#   have/VBP
#   authorized/VBN
#   a/DT
#   (Chunk
#     terrorist/JJ
#     surveillance/NN
#     program/NN
#     to/TO
#     aggressively/RB)
#   pursue/VB
#   the/DT
#   (Chunk international/JJ communications/NNS)
#   of/IN
#   (Chunk
#     suspected/JJ
#     al/JJ
#     Qaeda/NNP
#     operatives/NNS
#     and/CC
#     affiliates/NNS
#     to/TO
#     and/CC)
#   from/IN
#   (Chunk America/NNP Previous/NNP Presidents/NNS)
#   have/VBP
#   used/VBN
#   the/DT
#   (Chunk same/JJ constitutional/JJ authority/NN I/PRP)
#   have/VBP
#   (Chunk and/CC federal/JJ courts/NNS)
#   have/VBP
#   approved/VBN
#   the/DT
#   (Chunk use/NN)
#   of/IN
#   that/DT
#   (Chunk authority/NN Appropriate/NNP members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   The/DT
#   (Chunk terrorist/JJ surveillance/NN program/NN)
#   has/VBZ
#   helped/VBN
#   prevent/VB
#   (Chunk terrorist/JJ attacks/NNS It/PRP)
#   remains/VBZ
#   (Chunk essential/JJ to/TO)
#   the/DT
#   (Chunk security/NN)
#   of/IN
#   (Chunk America/NNP)
#   If/IN
#   (Chunk there/EX)
#   are/VBP
#   (Chunk people/NNS)
#   inside/IN
#   (Chunk our/PRP$ country/NN who/WP)
#   are/VBP
#   talking/VBG
#   with/IN
#   (Chunk al/JJ Qaeda/NNP we/PRP)
#   want/VBP
#   (Chunk to/TO)
#   know/VB
#   about/IN
#   (Chunk it/PRP)
#   because/IN
#   (Chunk we/PRP will/MD not/RB)
#   sit/VB
#   (Chunk back/RB and/CC wait/NN to/TO)
#   be/VB
#   hit/VBN
#   (Chunk again/RB Applause/NNP)
#   In/IN
#   (Chunk all/PDT)
#   these/DT
#   (Chunk areas/NNS)
#   from/IN
#   the/DT
#   (Chunk disruption/NN)
#   of/IN
#   (Chunk terror/NN networks/NNS to/TO victory/NN)
#   in/IN
#   (Chunk Iraq/NNP to/TO)
#   the/DT
#   (Chunk spread/NN)
#   of/IN
#   (Chunk freedom/NN and/CC hope/NN)
#   in/IN
#   (Chunk troubled/JJ regions/NNS we/PRP)
#   need/VBP
#   the/DT
#   (Chunk support/NN)
#   of/IN
#   (Chunk our/PRP$ friends/NNS and/CC allies/NNS To/TO)
#   draw/VB
#   that/IN
#   (Chunk support/NN we/PRP must/MD always/RB)
#   be/VB
#   (Chunk clear/JJ)
#   in/IN
#   (Chunk our/PRP$ principles/NNS and/CC willing/JJ to/TO)
#   act/VB
#   The/DT
#   (Chunk only/JJ alternative/NN to/TO American/JJ leadership/NN)
#   is/VBZ
#   a/DT
#   (Chunk
#     dramatically/RB
#     more/RBR
#     dangerous/JJ
#     and/CC
#     anxious/JJ
#     world/NN
#     Yet/CC
#     we/PRP
#     also/RB)
#   choose/VBP
#   (Chunk to/TO)
#   lead/VB
#   because/IN
#   (Chunk it/PRP)
#   is/VBZ
#   a/DT
#   (Chunk privilege/NN to/TO)
#   serve/VB
#   the/DT
#   (Chunk values/NNS that/WDT)
#   gave/VBD
#   (Chunk us/PRP birth/JJ American/JJ leaders/NNS)
#   from/IN
#   (Chunk
#     Roosevelt/NNP
#     to/TO
#     Truman/NNP
#     to/TO
#     Kennedy/NNP
#     to/TO
#     Reagan/NNP)
#   rejected/VBD
#   (Chunk isolation/NN and/CC retreat/NN)
#   because/IN
#   (Chunk they/PRP)
#   knew/VBD
#   that/IN
#   (Chunk America/NNP)
#   is/VBZ
#   (Chunk always/RB more/RBR secure/JJ when/WRB freedom/NN)
#   is/VBZ
#   on/IN
#   the/DT
#   (Chunk march/NN Our/PRP$ own/JJ generation/NN)
#   is/VBZ
#   in/IN
#   a/DT
#   (Chunk long/JJ war/NN)
#   against/IN
#   a/DT
#   (Chunk determined/JJ enemy/NN)
#   a/DT
#   (Chunk war/NN that/WDT will/MD)
#   be/VB
#   fought/VBN
#   by/IN
#   (Chunk Presidents/NNS)
#   of/IN
#   both/DT
#   (Chunk parties/NNS who/WP will/MD)
#   need/VB
#   (Chunk steady/JJ bipartisan/JJ support/NN)
#   from/IN
#   the/DT
#   (Chunk Congress/NNP And/CC)
#   tonight/VBD
#   (Chunk I/PRP)
#   ask/VBP
#   for/IN
#   (Chunk yours/NNS Together/NNP)
#   let/VBD
#   (Chunk us/PRP)
#   protect/VB
#   (Chunk our/PRP$ country/NN)
#   support/VB
#   the/DT
#   (Chunk men/NNS and/CC women/NNS who/WP)
#   defend/VBP
#   (Chunk us/PRP and/CC)
#   lead/VB
#   this/DT
#   (Chunk world/NN)
#   toward/IN
#   (Chunk freedom/NN Applause/NNP Here/RB)
#   at/IN
#   (Chunk home/NN America/NNP also/RB)
#   has/VBZ
#   a/DT
#   (Chunk great/JJ opportunity/NN We/PRP will/MD)
#   build/VB
#   the/DT
#   (Chunk prosperity/NN)
#   of/IN
#   (Chunk our/PRP$ country/NN)
#   by/IN
#   strengthening/VBG
#   (Chunk our/PRP$ economic/JJ leadership/NN)
#   in/IN
#   the/DT
#   (Chunk world/NN Our/PRP$ economy/NN)
#   is/VBZ
#   (Chunk healthy/JJ and/CC vigorous/JJ and/CC)
#   growing/VBG
#   (Chunk faster/RBR)
#   than/IN
#   (Chunk other/JJ major/JJ)
#   industrialized/VBN
#   (Chunk nations/NNS)
#   In/IN
#   the/DT
#   (Chunk last/JJ two/CD and/CC)
#   a/DT
#   (Chunk half/JJ years/NNS America/NNP)
#   has/VBZ
#   created/VBN
#   (Chunk million/CD new/JJ jobs/NNS more/JJR)
#   than/IN
#   (Chunk Japan/NNP and/CC)
#   the/DT
#   (Chunk European/NNP Union/NNP)
#   combined/VBD
#   (Chunk Applause/NNP Even/RB)
#   in/IN
#   the/DT
#   (Chunk face/NN)
#   of/IN
#   (Chunk
#     higher/JJR
#     energy/NN
#     prices/NNS
#     and/CC
#     natural/JJ
#     disasters/NNS)
#   the/DT
#   (Chunk American/JJ people/NNS)
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   (Chunk economic/JJ performance/NN that/WDT)
#   is/VBZ
#   the/DT
#   (Chunk envy/NN)
#   of/IN
#   the/DT
#   (Chunk world/NN)
#   The/DT
#   (Chunk American/JJ economy/NN)
#   is/VBZ
#   (Chunk preeminent/JJ but/CC we/PRP can/MD not/RB)
#   afford/VB
#   (Chunk to/TO)
#   be/VB
#   complacent/VBN
#   In/IN
#   a/DT
#   (Chunk dynamic/JJ world/NN economy/NN we/PRP)
#   are/VBP
#   seeing/VBG
#   (Chunk new/JJ competitors/NNS)
#   like/IN
#   (Chunk China/NNP and/CC India/NNP and/CC)
#   this/DT
#   creates/VBZ
#   (Chunk uncertainty/NN which/WDT)
#   makes/VBZ
#   (Chunk it/PRP easier/JJR to/TO)
#   feed/VB
#   (Chunk people/NNS s/JJ fears/NNS)
#   So/IN
#   (Chunk we/PRP)
#   re/VBP
#   seeing/VBG
#   some/DT
#   (Chunk old/JJ temptations/NNS)
#   return/VBP
#   (Chunk Protectionists/NNS)
#   want/VBP
#   (Chunk to/TO)
#   escape/VB
#   (Chunk competition/NN)
#   pretending/VBG
#   that/IN
#   (Chunk we/PRP can/MD)
#   keep/VB
#   (Chunk our/PRP$ high/JJ standard/NN)
#   of/IN
#   (Chunk living/NN)
#   while/IN
#   walling/VBG
#   (Chunk off/RP our/PRP$ economy/NN Others/NNS)
#   say/VBP
#   that/IN
#   the/DT
#   (Chunk government/NN)
#   needs/VBZ
#   (Chunk to/TO)
#   take/VB
#   a/DT
#   (Chunk larger/JJR role/NN)
#   in/IN
#   directing/VBG
#   the/DT
#   (Chunk economy/NN)
#   centralizing/VBG
#   (Chunk more/JJR power/NN)
#   in/IN
#   (Chunk Washington/NNP and/CC)
#   increasing/VBG
#   (Chunk taxes/NNS We/PRP)
#   hear/VBP
#   (Chunk claims/NNS)
#   that/IN
#   (Chunk immigrants/NNS)
#   are/VBP
#   (Chunk somehow/RB bad/JJ)
#   for/IN
#   the/DT
#   (Chunk economy/NN even/RB)
#   though/IN
#   this/DT
#   (Chunk economy/NN could/MD not/RB)
#   function/VB
#   without/IN
#   (Chunk them/PRP)
#   Applause/VBP
#   (Chunk All/PDT)
#   these/DT
#   are/VBP
#   (Chunk forms/NNS)
#   of/IN
#   (Chunk economic/JJ retreat/NN and/CC they/PRP)
#   lead/VBP
#   in/IN
#   the/DT
#   (Chunk same/JJ direction/NN)
#   toward/IN
#   a/DT
#   (Chunk
#     stagnant/NN
#     and/CC
#     second/JJ
#     rate/NN
#     economy/NN
#     Tonight/NNP
#     I/PRP
#     will/MD)
#   set/VB
#   (Chunk out/RP)
#   a/DT
#   (Chunk better/JJR path/NN)
#   an/DT
#   (Chunk agenda/NN)
#   for/IN
#   a/DT
#   (Chunk nation/NN that/WDT)
#   competes/VBZ
#   with/IN
#   (Chunk confidence/NN)
#   an/DT
#   (Chunk agenda/NN that/WDT will/MD)
#   raise/VB
#   (Chunk standards/NNS)
#   of/IN
#   (Chunk living/NN and/CC)
#   generate/VB
#   (Chunk new/JJ jobs/NNS Americans/NNPS should/MD not/RB)
#   fear/VB
#   (Chunk our/PRP$ economic/JJ future/NN)
#   because/IN
#   (Chunk we/PRP)
#   intend/VBP
#   (Chunk to/TO)
#   shape/VB
#   (Chunk it/PRP Keeping/NNP America/NNP competitive/JJ begins/NNS)
#   with/IN
#   keeping/VBG
#   (Chunk our/PRP$ economy/NN)
#   growing/VBG
#   (Chunk And/CC our/PRP$ economy/NN)
#   grows/VBZ
#   (Chunk when/WRB Americans/NNPS)
#   have/VBP
#   (Chunk more/JJR)
#   of/IN
#   (Chunk their/PRP$ own/JJ money/NN to/TO)
#   spend/VB
#   (Chunk save/NN and/CC invest/NN)
#   In/IN
#   the/DT
#   (Chunk last/JJ five/CD years/NNS)
#   the/DT
#   (Chunk tax/NN relief/NN you/PRP)
#   passed/VBN
#   has/VBZ
#   left/VBN
#   (Chunk billion/CD)
#   in/IN
#   the/DT
#   (Chunk hands/NNS)
#   of/IN
#   (Chunk
#     American/JJ
#     workers/NNS
#     investors/NNS
#     small/JJ
#     businesses/NNS
#     and/CC
#     families/NNS
#     and/CC
#     they/PRP)
#   have/VBP
#   used/VBN
#   (Chunk it/PRP to/TO)
#   help/VB
#   produce/VB
#   (Chunk more/JJR)
#   than/IN
#   (Chunk four/CD years/NNS)
#   of/IN
#   (Chunk uninterrupted/JJ economic/JJ growth/NN Applause/NNP Yet/CC)
#   the/DT
#   (Chunk tax/NN relief/NN)
#   is/VBZ
#   set/VBN
#   (Chunk to/TO)
#   expire/VB
#   in/IN
#   the/DT
#   (Chunk next/JJ few/JJ years/NNS)
#   If/IN
#   (Chunk we/PRP)
#   do/VBP
#   (Chunk nothing/NN American/JJ families/NNS will/MD)
#   face/VB
#   a/DT
#   (Chunk massive/JJ tax/NN increase/NN they/PRP)
#   do/VBP
#   (Chunk not/RB)
#   expect/VB
#   (Chunk and/CC will/MD not/RB)
#   welcome/VB
#   Because/IN
#   (Chunk America/NNP)
#   needs/VBZ
#   (Chunk more/JJR)
#   than/IN
#   a/DT
#   (Chunk temporary/JJ expansion/NN we/PRP)
#   need/VBP
#   (Chunk more/JJR)
#   than/IN
#   (Chunk temporary/JJ tax/NN relief/NN I/PRP)
#   urge/VBP
#   the/DT
#   (Chunk Congress/NNP to/TO)
#   act/VB
#   (Chunk responsibly/RB and/CC)
#   make/VB
#   the/DT
#   (Chunk
#     tax/NN
#     cuts/NNS
#     permanent/JJ
#     Applause/NNP
#     Keeping/NNP
#     America/NNP
#     competitive/JJ)
#   requires/VBZ
#   (Chunk us/PRP to/TO)
#   be/VB
#   (Chunk good/JJ stewards/NNS)
#   of/IN
#   (Chunk tax/NN dollars/NNS)
#   Every/DT
#   (Chunk year/NN)
#   of/IN
#   (Chunk my/PRP$ presidency/NN we/PRP)
#   ve/VBP
#   reduced/VBD
#   the/DT
#   (Chunk growth/NN)
#   of/IN
#   (Chunk
#     non/JJ
#     security/NN
#     discretionary/JJ
#     spending/NN
#     and/CC
#     last/JJ
#     year/NN
#     you/PRP)
#   passed/VBD
#   (Chunk bills/NNS)
#   that/IN
#   cut/VBD
#   this/DT
#   (Chunk spending/NN)
#   This/DT
#   (Chunk year/NN my/PRP$ budget/NN will/MD)
#   cut/VB
#   (Chunk it/PRP again/RB and/CC)
#   reduce/VB
#   (Chunk or/CC)
#   eliminate/VB
#   (Chunk more/JJR)
#   than/IN
#   (Chunk programs/NNS that/WDT)
#   are/VBP
#   performing/VBG
#   (Chunk
#     poorly/RB
#     or/CC
#     not/RB
#     fulfilling/JJ
#     essential/JJ
#     priorities/NNS)
#   By/IN
#   passing/VBG
#   these/DT
#   (Chunk reforms/NNS we/PRP will/MD)
#   save/VB
#   the/DT
#   (Chunk American/NNP taxpayer/NN)
#   another/DT
#   (Chunk billion/CD next/JJ year/NN and/CC)
#   stay/VB
#   on/IN
#   (Chunk track/NN to/TO)
#   cut/VB
#   the/DT
#   (Chunk deficit/NN)
#   in/IN
#   (Chunk half/NN)
#   by/IN
#   (Chunk Applause/NNP I/PRP)
#   am/VBP
#   (Chunk pleased/JJ)
#   that/IN
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   (Chunk earmark/NN reform/NN)
#   because/IN
#   the/DT
#   (Chunk federal/JJ budget/NN)
#   has/VBZ
#   (Chunk
#     too/RB
#     many/JJ
#     special/JJ
#     interest/NN
#     projects/NNS
#     Applause/NNP
#     And/CC
#     we/PRP
#     can/MD)
#   tackle/VB
#   this/DT
#   (Chunk problem/NN together/RB)
#   if/IN
#   (Chunk you/PRP)
#   pass/VBP
#   the/DT
#   (Chunk line/NN item/NN veto/NN)
#   Applause/IN
#   (Chunk We/PRP must/MD also/RB)
#   confront/VB
#   the/DT
#   (Chunk larger/JJR challenge/NN)
#   of/IN
#   (Chunk mandatory/JJ spending/NN or/CC entitlements/NNS)
#   This/DT
#   (Chunk year/NN)
#   the/DT
#   (Chunk first/JJ)
#   of/IN
#   about/IN
#   (Chunk million/CD baby/NN boomers/NNS)
#   turn/VBP
#   including/VBG
#   (Chunk two/CD)
#   of/IN
#   (Chunk
#     my/PRP$
#     Dad/NNP
#     s/NN
#     favorite/NN
#     people/NNS
#     me/PRP
#     and/CC
#     President/NNP
#     Clinton/NNP
#     Laughter/NNP)
#   This/DT
#   (Chunk milestone/NN)
#   is/VBZ
#   (Chunk more/JJR)
#   than/IN
#   a/DT
#   (Chunk personal/JJ crisis/NN laughter/NN it/PRP)
#   is/VBZ
#   a/DT
#   (Chunk national/JJ challenge/NN)
#   The/DT
#   (Chunk retirement/NN)
#   of/IN
#   the/DT
#   (Chunk baby/NN boom/NN generation/NN will/MD)
#   put/VB
#   (Chunk unprecedented/JJ strains/NNS)
#   on/IN
#   the/DT
#   (Chunk federal/JJ government/NN)
#   By/IN
#   spending/VBG
#   for/IN
#   (Chunk
#     Social/NNP
#     Security/NNP
#     Medicare/NNP
#     and/CC
#     Medicaid/NNP
#     alone/RB
#     will/MD)
#   be/VB
#   (Chunk almost/RB percent/NN)
#   of/IN
#   the/DT
#   (Chunk entire/JJ federal/JJ budget/NN And/CC)
#   that/DT
#   (Chunk will/MD)
#   present/VB
#   (Chunk future/JJ Congresses/NNS)
#   with/IN
#   (Chunk impossible/JJ choices/NNS)
#   staggering/VBG
#   (Chunk tax/NN increases/NNS)
#   immense/VBP
#   (Chunk deficits/NNS or/CC deep/JJ cuts/NNS)
#   in/IN
#   every/DT
#   (Chunk category/NN)
#   of/IN
#   (Chunk spending/NN Congress/NNP)
#   did/VBD
#   (Chunk not/RB)
#   act/VB
#   (Chunk last/JJ year/NN)
#   on/IN
#   (Chunk my/PRP$ proposal/NN to/TO)
#   save/VB
#   (Chunk Social/NNP Security/NNP applause/NN yet/RB)
#   the/DT
#   rising/VBG
#   (Chunk cost/NN)
#   of/IN
#   (Chunk entitlements/NNS)
#   is/VBZ
#   a/DT
#   (Chunk problem/NN that/WDT)
#   is/VBZ
#   (Chunk not/RB)
#   going/VBG
#   (Chunk away/RB Applause/NNP And/CC)
#   every/DT
#   (Chunk year/NN we/PRP)
#   fail/VBP
#   (Chunk to/TO)
#   act/VB
#   the/DT
#   (Chunk situation/NN)
#   gets/VBZ
#   (Chunk worse/JJR So/NNP tonight/JJ I/PRP)
#   ask/VBP
#   (Chunk you/PRP to/TO)
#   join/VB
#   (Chunk me/PRP)
#   in/IN
#   creating/VBG
#   a/DT
#   (Chunk commission/NN to/TO)
#   examine/VB
#   the/DT
#   (Chunk full/JJ impact/NN)
#   of/IN
#   (Chunk baby/NN boom/NN retirements/NNS)
#   on/IN
#   (Chunk Social/NNP Security/NNP Medicare/NNP and/CC Medicaid/NNP)
#   This/DT
#   (Chunk commission/NN should/MD)
#   include/VB
#   (Chunk members/NNS)
#   of/IN
#   (Chunk Congress/NNP)
#   of/IN
#   both/DT
#   (Chunk parties/NNS and/CC)
#   offer/VBP
#   (Chunk bipartisan/JJ solutions/NNS We/PRP)
#   need/VBP
#   (Chunk to/TO)
#   put/VB
#   (Chunk
#     aside/RP
#     partisan/JJ
#     politics/NNS
#     and/CC
#     work/NN
#     together/RB
#     and/CC)
#   get/VB
#   this/DT
#   (Chunk problem/NN)
#   solved/VBD
#   (Chunk Applause/NNP Keeping/NNP America/NNP competitive/JJ)
#   requires/VBZ
#   (Chunk us/PRP to/TO)
#   open/VB
#   (Chunk more/JJR markets/NNS)
#   for/IN
#   all/DT
#   that/DT
#   (Chunk Americans/NNPS)
#   make/VBP
#   (Chunk and/CC)
#   grow/VB
#   (Chunk One/CD)
#   out/IN
#   of/IN
#   every/DT
#   (Chunk five/CD factory/NN jobs/NNS)
#   in/IN
#   (Chunk America/NNP)
#   is/VBZ
#   related/VBN
#   (Chunk to/TO global/JJ trade/NN and/CC we/PRP)
#   want/VBP
#   (Chunk people/NNS everywhere/RB to/TO)
#   buy/VB
#   (Chunk American/JJ)
#   With/IN
#   (Chunk open/JJ markets/NNS and/CC)
#   a/DT
#   (Chunk level/JJ playing/NN field/NN)
#   no/DT
#   (Chunk one/NN can/MD)
#   out/VB
#   produce/VB
#   (Chunk or/CC)
#   out/IN
#   compete/VBP
#   the/DT
#   (Chunk
#     American/JJ
#     worker/NN
#     Applause/NNP
#     Keeping/NNP
#     America/NNP
#     competitive/JJ)
#   requires/VBZ
#   an/DT
#   (Chunk immigration/NN system/NN that/WDT)
#   upholds/VBZ
#   (Chunk our/PRP$ laws/NNS)
#   reflects/VBZ
#   (Chunk our/PRP$ values/NNS and/CC)
#   serves/VBZ
#   the/DT
#   (Chunk interests/NNS)
#   of/IN
#   (Chunk our/PRP$ economy/NN Our/PRP$ nation/NN)
#   needs/VBZ
#   (Chunk orderly/JJ and/CC secure/JJ borders/NNS)
#   Applause/VBP
#   (Chunk To/TO)
#   meet/VB
#   this/DT
#   (Chunk goal/NN we/PRP must/MD)
#   have/VB
#   (Chunk
#     stronger/JJR
#     immigration/NN
#     enforcement/NN
#     and/CC
#     border/NN
#     protection/NN
#     Applause/NNP
#     And/CC
#     we/PRP
#     must/MD)
#   have/VB
#   a/DT
#   (Chunk
#     rational/JJ
#     humane/NN
#     guest/JJS
#     worker/NN
#     program/NN
#     that/WDT)
#   rejects/VBZ
#   (Chunk amnesty/JJ allows/NNS temporary/JJ jobs/NNS)
#   for/IN
#   (Chunk people/NNS who/WP)
#   seek/VBP
#   (Chunk them/PRP legally/RB and/CC reduces/NNS)
#   smuggling/VBG
#   (Chunk and/CC crime/NN)
#   at/IN
#   the/DT
#   (Chunk
#     border/NN
#     Applause/NNP
#     Keeping/NNP
#     America/NNP
#     competitive/JJ)
#   requires/VBZ
#   (Chunk
#     affordable/JJ
#     health/NN
#     care/NN
#     Applause/NNP
#     Our/PRP$
#     government/NN)
#   has/VBZ
#   a/DT
#   (Chunk responsibility/NN to/TO)
#   provide/VB
#   (Chunk health/NN care/NN)
#   for/IN
#   the/DT
#   (Chunk poor/JJ and/CC)
#   the/DT
#   (Chunk elderly/JJ and/CC we/PRP)
#   are/VBP
#   meeting/VBG
#   that/IN
#   (Chunk responsibility/NN Applause/NNP)
#   For/IN
#   all/DT
#   (Chunk Americans/NNPS)
#   for/IN
#   all/DT
#   (Chunk Americans/NNPS we/PRP must/MD)
#   confront/VB
#   the/DT
#   rising/VBG
#   (Chunk cost/NN)
#   of/IN
#   (Chunk care/NN)
#   strengthen/VBZ
#   the/DT
#   (Chunk
#     doctor/NN
#     patient/NN
#     relationship/NN
#     and/CC
#     help/NN
#     people/NNS)
#   afford/VBP
#   the/DT
#   (Chunk insurance/NN coverage/NN they/PRP)
#   need/VBP
#   Applause/IN
#   (Chunk We/PRP will/MD)
#   make/VB
#   (Chunk wider/JJR use/NN)
#   of/IN
#   (Chunk
#     electronic/JJ
#     records/NNS
#     and/CC
#     other/JJ
#     health/NN
#     information/NN
#     technology/NN
#     to/TO)
#   help/VB
#   control/VB
#   (Chunk costs/NNS and/CC)
#   reduce/VB
# ...
#   since/IN
#   the/DT
#   (Chunk s/NN Welfare/NNP cases/NNS)
#   have/VBP
#   dropped/VBN
#   by/IN
#   (Chunk more/JJR)
#   than/IN
#   (Chunk half/NN)
#   over/IN
#   the/DT
#   (Chunk past/JJ decade/NN Drug/NNP use/NN)
#   among/IN
#   (Chunk youth/NN)
#   is/VBZ
#   (Chunk down/RB percent/JJ)
#   since/IN
#   (Chunk There/EX)
#   are/VBP
#   (Chunk fewer/JJR abortions/NNS)
#   in/IN
#   (Chunk America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   (Chunk point/NN)
#   in/IN
#   the/DT
#   (Chunk last/JJ three/CD decades/NNS and/CC)
#   the/DT
#   (Chunk number/NN)
#   of/IN
#   (Chunk children/NNS)
#   born/VBN
#   (Chunk to/TO)
#   teenage/VB
#   (Chunk mothers/NNS)
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   (Chunk dozen/NN years/NNS)
#   in/IN
#   a/DT
#   (Chunk row/NN)
#   Applause/IN
#   These/DT
#   (Chunk gains/NNS)
#   are/VBP
#   (Chunk evidence/NN)
#   of/IN
#   a/DT
#   (Chunk quiet/JJ transformation/NN)
#   a/DT
#   (Chunk revolution/NN)
#   of/IN
#   (Chunk conscience/NN)
#   in/IN
#   (Chunk which/WDT)
#   a/DT
#   rising/VBG
#   (Chunk generation/NN)
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   (Chunk life/NN)
#   of/IN
#   (Chunk personal/JJ responsibility/NN)
#   is/VBZ
#   a/DT
#   (Chunk life/NN)
#   of/IN
#   (Chunk fulfillment/JJ Government/NNP)
#   has/VBZ
#   played/VBN
#   a/DT
#   (Chunk role/NN Wise/NNP policies/NNS such/JJ)
#   as/IN
#   (Chunk
#     welfare/NN
#     reform/NN
#     and/CC
#     drug/NN
#     education/NN
#     and/CC
#     support/NN)
#   for/IN
#   (Chunk abstinence/NN and/CC adoption/NN)
#   have/VBP
#   made/VBN
#   a/DT
#   (Chunk difference/NN)
#   in/IN
#   the/DT
#   (Chunk character/NN)
#   of/IN
#   (Chunk
#     our/PRP$
#     country/NN
#     And/CC
#     everyone/NN
#     here/RB
#     tonight/JJ
#     Democrat/NNP
#     and/CC
#     Republican/NNP)
#   has/VBZ
#   a/DT
#   (Chunk right/NN to/TO)
#   be/VB
#   (Chunk proud/JJ)
#   of/IN
#   this/DT
#   (Chunk
#     record/NN
#     Applause/NNP
#     Yet/NNP
#     many/JJ
#     Americans/NNPS
#     especially/RB
#     parents/NNS
#     still/RB)
#   have/VBP
#   (Chunk deep/JJ concerns/NNS)
#   about/IN
#   the/DT
#   (Chunk direction/NN)
#   of/IN
#   (Chunk our/PRP$ culture/NN and/CC)
#   the/DT
#   (Chunk health/NN)
#   of/IN
#   (Chunk our/PRP$ most/JJS basic/JJ institutions/NNS They/PRP)
#   re/VBP
#   concerned/VBN
#   about/IN
#   (Chunk unethical/JJ conduct/NN)
#   by/IN
#   (Chunk public/JJ officials/NNS and/CC)
#   discouraged/VBN
#   by/IN
#   (Chunk activist/NN courts/NNS that/WDT)
#   try/VBP
#   (Chunk to/TO)
#   redefine/VB
#   (Chunk marriage/NN They/PRP)
#   worry/VBP
#   about/IN
#   (Chunk children/NNS)
#   in/IN
#   (Chunk our/PRP$ society/NN who/WP)
#   need/VBP
#   (Chunk direction/NN and/CC love/NN and/CC)
#   about/IN
#   (Chunk fellow/JJ citizens/NNS still/RB)
#   displaced/VBN
#   by/IN
#   (Chunk natural/JJ disaster/NN and/CC)
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   (Chunk treatable/JJ diseases/NNS)
#   As/IN
#   (Chunk we/PRP)
#   look/VBP
#   at/IN
#   these/DT
#   (Chunk challenges/NNS we/PRP must/MD never/RB)
#   give/VB
#   in/IN
#   (Chunk to/TO)
#   the/DT
#   (Chunk belief/NN)
#   that/IN
#   (Chunk America/NNP)
#   is/VBZ
#   in/IN
#   (Chunk decline/NN or/CC)
#   that/IN
#   (Chunk our/PRP$ culture/NN)
#   is/VBZ
#   doomed/VBN
#   (Chunk to/TO)
#   unravel/VB
#   The/DT
#   (Chunk American/JJ people/NNS)
#   know/VBP
#   (Chunk better/JJR)
#   than/IN
#   that/IN
#   (Chunk We/PRP)
#   have/VBP
#   proven/VBN
#   the/DT
#   (Chunk pessimists/NNS wrong/JJ before/RB and/CC we/PRP will/MD)
#   do/VB
#   (Chunk it/PRP again/RB)
#   Applause/IN
#   (Chunk A/NNP hopeful/JJ society/NN)
#   depends/VBZ
#   on/IN
#   (Chunk courts/NNS)
#   that/IN
#   deliver/VBP
#   (Chunk equal/JJ justice/NN)
#   under/IN
#   the/DT
#   (Chunk law/NN)
#   The/DT
#   (Chunk Supreme/NNP Court/NNP now/RB)
#   has/VBZ
#   (Chunk two/CD superb/JJ new/JJ members/NNS new/JJ members/NNS)
#   on/IN
#   (Chunk
#     its/PRP$
#     bench/NN
#     Chief/NNP
#     Justice/NNP
#     John/NNP
#     Roberts/NNP
#     and/CC
#     Justice/NNP
#     Sam/NNP
#     Alito/NNP
#     Applause/NNP
#     I/PRP)
#   thank/VBD
#   the/DT
#   (Chunk Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   (Chunk them/PRP I/PRP will/MD)
#   continue/VB
#   (Chunk to/TO)
#   nominate/VB
#   (Chunk men/NNS and/CC women/NNS who/WP)
#   understand/VBP
#   that/IN
#   (Chunk judges/NNS must/MD)
#   be/VB
#   (Chunk servants/NNS)
#   of/IN
#   the/DT
#   (Chunk law/NN and/CC not/RB)
#   legislate/VB
#   from/IN
#   the/DT
#   (Chunk bench/NN Applause/NNP Today/NNP)
#   marks/VBZ
#   the/DT
#   (Chunk official/JJ retirement/NN)
#   of/IN
#   a/DT
#   (Chunk very/RB special/JJ American/NNP)
#   For/IN
#   (Chunk years/NNS)
#   of/IN
#   (Chunk faithful/JJ service/NN to/TO our/PRP$ nation/NN)
#   the/DT
#   (Chunk United/NNP States/NNPS)
#   is/VBZ
#   (Chunk
#     grateful/JJ
#     to/TO
#     Justice/NNP
#     Sandra/NNP
#     Day/NNP
#     O/NNP
#     Connor/NNP
#     Applause/NNP
#     A/NNP
#     hopeful/JJ
#     society/NN)
#   has/VBZ
#   (Chunk institutions/NNS)
#   of/IN
#   (Chunk science/NN and/CC medicine/NN that/WDT)
#   do/VBP
#   (Chunk not/RB)
#   cut/VB
#   (Chunk ethical/JJ corners/NNS and/CC)
#   that/DT
#   recognize/VBP
#   the/DT
#   (Chunk matchless/NN value/NN)
#   of/IN
#   every/DT
#   (Chunk life/NN Tonight/NNP I/PRP)
#   ask/VBP
#   (Chunk you/PRP to/TO)
#   pass/VB
#   (Chunk legislation/NN to/TO)
#   prohibit/VB
#   the/DT
#   (Chunk most/RBS egregious/JJ abuses/NNS)
#   of/IN
#   (Chunk medical/JJ research/NN human/JJ cloning/NN)
#   in/IN
#   all/DT
#   (Chunk its/PRP$ forms/NNS)
#   creating/VBG
#   (Chunk or/CC)
#   implanting/VBG
#   (Chunk embryos/NN)
#   for/IN
#   (Chunk experiments/NNS)
#   creating/VBG
#   (Chunk human/JJ animal/JJ hybrids/NNS and/CC)
#   buying/VBG
#   (Chunk selling/NN or/CC)
#   patenting/VBG
#   (Chunk human/JJ embryos/NN Human/NNP life/NN)
#   is/VBZ
#   a/DT
#   (Chunk gift/NN)
#   from/IN
#   (Chunk our/PRP$ Creator/NN and/CC)
#   that/IN
#   (Chunk gift/NN should/MD never/RB)
#   be/VB
#   discarded/VBN
#   devalued/VBN
#   (Chunk or/CC)
#   put/VBN
#   (Chunk up/RP)
#   for/IN
#   (Chunk sale/NN)
#   Applause/VBP
#   A/DT
#   (Chunk hopeful/JJ society/NN)
#   expects/VBZ
#   elected/VBN
#   (Chunk officials/NNS to/TO)
#   uphold/VB
#   the/DT
#   (Chunk public/JJ trust/NN Applause/NNP Honorable/NNP people/NNS)
#   in/IN
#   both/DT
#   (Chunk parties/NNS)
#   are/VBP
#   working/VBG
#   on/IN
#   (Chunk reforms/NNS to/TO)
#   strengthen/VB
#   the/DT
#   (Chunk ethical/JJ standards/NNS)
#   of/IN
#   (Chunk Washington/NNP I/PRP)
#   support/VBP
#   (Chunk your/PRP$ efforts/NNS)
#   Each/DT
#   of/IN
#   (Chunk us/PRP)
#   has/VBZ
#   made/VBN
#   a/DT
#   (Chunk pledge/NN to/TO)
#   be/VB
#   (Chunk worthy/JJ)
#   of/IN
#   (Chunk public/JJ responsibility/NN and/CC)
#   that/DT
#   is/VBZ
#   a/DT
#   (Chunk pledge/NN we/PRP must/MD never/RB)
#   forget/VB
#   (Chunk never/RB dismiss/NN and/CC never/RB betray/NN Applause/NNP)
#   As/IN
#   (Chunk we/PRP)
#   renew/VBP
#   the/DT
#   (Chunk promise/NN)
#   of/IN
#   (Chunk our/PRP$ institutions/NNS)
#   let/VB
#   (Chunk us/PRP also/RB)
#   show/VBP
#   the/DT
#   (Chunk character/NN)
#   of/IN
#   (Chunk America/NNP)
#   in/IN
#   (Chunk our/PRP$ compassion/NN and/CC care/NN)
#   for/IN
#   (Chunk one/CD)
#   another/DT
#   A/DT
#   (Chunk hopeful/JJ society/NN)
#   gives/VBZ
#   (Chunk special/JJ attention/NN to/TO children/NNS who/WP)
#   lack/VBP
#   (Chunk direction/NN and/CC)
#   love/VB
#   Through/IN
#   the/DT
#   (Chunk Helping/NNP America/NNP)
#   s/VBD
#   (Chunk Youth/NNP Initiative/NNP we/PRP)
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   (Chunk adults/NNS to/TO)
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   (Chunk life/NN)
#   of/IN
#   a/DT
#   (Chunk child/NN and/CC)
#   this/DT
#   (Chunk good/JJ work/NN)
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   (Chunk our/PRP$ First/NNP Lady/NNP Laura/NNP Bush/NNP)
#   Applause/IN
#   This/DT
#   (Chunk year/NN we/PRP will/MD)
#   add/VB
#   (Chunk resources/NNS to/TO)
#   encourage/VB
#   (Chunk young/JJ people/NNS to/TO)
#   stay/VB
#   in/IN
#   (Chunk school/NN so/RB more/JJR)
#   of/IN
#   (Chunk America/NNP s/FW youth/NN can/MD)
#   raise/VB
#   (Chunk their/PRP$ sights/NNS and/CC)
#   achieve/VBP
#   (Chunk their/PRP$ dreams/NNS)
#   A/DT
#   (Chunk hopeful/JJ society/NN)
#   comes/VBZ
#   (Chunk to/TO)
#   the/DT
#   (Chunk aid/NN)
#   of/IN
#   (Chunk fellow/JJ citizens/NNS)
#   in/IN
#   (Chunk times/NNS)
#   of/IN
#   (Chunk suffering/NN and/CC emergency/NN and/CC stays/NNS)
#   at/IN
#   (Chunk it/PRP)
#   until/IN
#   (Chunk they/PRP)
#   re/VBP
#   (Chunk back/RB)
#   on/IN
#   (Chunk their/PRP$ feet/NNS So/RB far/RB)
#   the/DT
#   (Chunk federal/JJ government/NN)
#   has/VBZ
#   committed/VBN
#   (Chunk billion/CD to/TO)
#   the/DT
#   (Chunk people/NNS)
#   of/IN
#   the/DT
#   (Chunk Gulf/NNP Coast/NNP and/CC New/NNP Orleans/NNP We/PRP)
#   re/VBP
#   removing/VBG
#   (Chunk debris/NN and/CC repairing/NN highways/NNS and/CC)
#   rebuilding/VBG
#   (Chunk stronger/JJR levees/NNS We/PRP)
#   re/VBP
#   providing/VBG
#   (Chunk
#     business/NN
#     loans/NNS
#     and/CC
#     housing/NN
#     assistance/NN
#     Yet/RB)
#   as/IN
#   (Chunk we/PRP)
#   meet/VBP
#   these/DT
#   (Chunk immediate/JJ needs/NNS we/PRP must/MD also/RB)
#   address/VB
#   (Chunk deeper/JJR challenges/NNS that/WDT)
#   existed/VBD
#   before/IN
#   the/DT
#   (Chunk storm/NN)
#   arrived/VBN
#   In/IN
#   (Chunk New/NNP Orleans/NNP and/CC)
#   in/IN
#   (Chunk other/JJ places/NNS many/JJ)
#   of/IN
#   (Chunk our/PRP$ fellow/JJ citizens/NNS)
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   (Chunk promise/NN)
#   of/IN
#   (Chunk our/PRP$ country/NN)
#   The/DT
#   (Chunk answer/NN)
#   is/VBZ
#   (Chunk
#     not/RB
#     only/RB
#     temporary/JJ
#     relief/NN
#     but/CC
#     schools/NNS
#     that/WDT)
#   teach/VBP
#   every/DT
#   (Chunk child/NN and/CC job/NN skills/NNS)
#   that/IN
#   bring/VBG
#   (Chunk
#     upward/JJ
#     mobility/NN
#     and/CC
#     more/JJR
#     opportunities/NNS
#     to/TO)
#   own/VB
#   a/DT
#   (Chunk home/NN and/CC)
#   start/VB
#   a/DT
#   (Chunk business/NN)
#   As/IN
#   (Chunk we/PRP)
#   recover/VBP
#   from/IN
#   a/DT
#   (Chunk disaster/NN let/NN us/PRP also/RB work/NN)
#   for/IN
#   the/DT
#   (Chunk day/NN when/WRB)
#   all/DT
#   (Chunk Americans/NNPS)
#   are/VBP
#   protected/VBN
#   by/IN
#   (Chunk justice/NN equal/JJ)
#   in/IN
#   (Chunk hope/NN and/CC rich/JJ)
#   in/IN
#   (Chunk opportunity/NN)
#   Applause/VBP
#   A/DT
#   (Chunk hopeful/JJ society/NN acts/NNS boldly/RB to/TO)
#   fight/VB
#   (Chunk diseases/NNS)
#   like/IN
#   (Chunk HIV/NNP AIDS/NNP which/WDT can/MD)
#   be/VB
#   prevented/VBN
#   (Chunk and/CC)
#   treated/VBN
#   (Chunk and/CC)
#   defeated/VBN
#   (Chunk More/JJR)
#   than/IN
#   a/DT
#   (Chunk million/CD Americans/NNPS)
#   live/VBP
#   with/IN
#   (Chunk HIV/NNP and/CC half/NN)
#   of/IN
#   all/DT
#   (Chunk AIDS/NNP cases/NNS)
#   occur/VBP
#   among/IN
#   (Chunk African/JJ Americans/NNPS I/PRP)
#   ask/VBP
#   (Chunk Congress/NNP to/TO)
#   reform/VB
#   (Chunk and/CC)
#   reauthorize/VB
#   the/DT
#   (Chunk Ryan/NNP White/NNP Act/NNP and/CC)
#   provide/VB
#   (Chunk new/JJ funding/NN to/TO states/NNS)
#   so/IN
#   (Chunk we/PRP)
#   end/VBP
#   the/DT
#   (Chunk waiting/NN lists/NNS)
#   for/IN
#   (Chunk AIDS/NNP medicines/NNS)
#   in/IN
#   (Chunk America/NNP Applause/NNP We/PRP will/MD also/RB)
#   lead/VB
#   a/DT
#   (Chunk nationwide/JJ effort/NN)
#   working/VBG
#   (Chunk closely/RB)
#   with/IN
#   (Chunk African/JJ American/JJ churches/NNS and/CC faith/NNS)
#   based/VBN
#   (Chunk groups/NNS to/TO)
#   deliver/VB
#   (Chunk rapid/JJ HIV/NNP tests/NNS to/TO millions/NNS)
#   end/VB
#   the/DT
#   (Chunk stigma/NN)
#   of/IN
#   (Chunk AIDS/NNP and/CC)
#   come/VBN
#   (Chunk closer/RBR to/TO)
#   the/DT
#   (Chunk day/NN when/WRB there/EX)
#   are/VBP
#   no/DT
#   (Chunk new/JJ infections/NNS)
#   in/IN
#   (Chunk America/NNP Applause/NNP Fellow/NNP)
#   citizens/VBZ
#   (Chunk we/PRP)
#   ve/VBP
#   been/VBN
#   called/VBN
#   (Chunk to/TO leadership/NN)
#   in/IN
#   a/DT
#   (Chunk period/NN)
#   of/IN
#   (Chunk consequence/NN We/PRP)
#   ve/VBP
#   entered/VBD
#   a/DT
#   (Chunk great/JJ ideological/JJ conflict/NN we/PRP)
#   did/VBD
#   (Chunk nothing/NN to/TO)
#   invite/VB
#   (Chunk We/PRP)
#   see/VBP
#   (Chunk great/JJ changes/NNS)
#   in/IN
#   (Chunk science/NN and/CC commerce/NN that/WDT will/MD)
#   influence/VB
#   all/DT
#   (Chunk our/PRP$ lives/NNS Sometimes/RB it/PRP can/MD)
#   seem/VB
#   that/DT
#   (Chunk history/NN)
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   (Chunk wide/JJ arc/NN)
#   toward/IN
#   an/DT
#   (Chunk unknown/JJ shore/NN Yet/CC)
#   the/DT
#   (Chunk destination/NN)
#   of/IN
#   (Chunk history/NN)
#   is/VBZ
#   determined/VBN
#   by/IN
#   (Chunk human/JJ action/NN and/CC)
#   every/DT
#   (Chunk great/JJ movement/NN)
#   of/IN
#   (Chunk history/NN)
#   comes/VBZ
#   (Chunk to/TO)
#   a/DT
#   (Chunk point/NN)
#   of/IN
#   choosing/VBG
#   (Chunk Lincoln/NNP could/MD)
#   have/VB
#   accepted/VBN
#   (Chunk peace/NN)
#   at/IN
#   the/DT
#   (Chunk cost/NN)
#   of/IN
#   (Chunk
#     disunity/NN
#     and/CC
#     continued/JJ
#     slavery/NN
#     Martin/NNP
#     Luther/NNP
#     King/NNP
#     could/MD)
#   have/VB
#   stopped/VBN
#   at/IN
#   (Chunk Birmingham/NNP or/CC)
#   at/IN
#   (Chunk Selma/NNP and/CC)
#   achieved/VBD
#   (Chunk only/RB half/PDT)
#   a/DT
#   (Chunk victory/NN)
#   over/IN
#   (Chunk segregation/NN)
#   The/DT
#   (Chunk United/NNP States/NNPS could/MD)
#   have/VB
#   accepted/VBN
#   the/DT
#   (Chunk permanent/JJ division/NN)
#   of/IN
#   (Chunk Europe/NNP and/CC)
#   been/VBN
#   (Chunk complicit/NNS)
#   in/IN
#   the/DT
#   (Chunk oppression/NN)
#   of/IN
#   (Chunk others/NNS Today/NNP)
#   having/VBG
#   come/VBN
#   (Chunk far/RB)
#   in/IN
#   (Chunk our/PRP$ own/JJ historical/JJ journey/NN we/PRP must/MD)
#   decide/VB
#   (Chunk Will/NNP we/PRP)
#   turn/VBP
#   (Chunk back/RB or/CC finish/JJ well/RB)
#   Before/IN
#   (Chunk history/NN)
#   is/VBZ
#   written/VBN
#   (Chunk down/RP)
#   in/IN
#   (Chunk books/NNS it/PRP)
#   is/VBZ
#   written/VBN
#   in/IN
#   (Chunk courage/NN)
#   Like/IN
#   (Chunk Americans/NNPS)
#   before/IN
#   (Chunk us/PRP we/PRP will/MD)
#   show/VB
#   that/DT
#   (Chunk courage/NN and/CC we/PRP will/MD)
#   finish/VB
#   (Chunk well/RB We/PRP will/MD)
#   lead/VB
#   (Chunk freedom/NN s/JJ advance/NN We/PRP will/MD)
#   compete/VB
#   (Chunk and/CC)
#   excel/VB
#   in/IN
#   the/DT
#   (Chunk global/JJ economy/NN We/PRP will/MD)
#   renew/VB
#   the/DT
#   defining/VBG
#   (Chunk moral/JJ commitments/NNS)
#   of/IN
#   this/DT
#   (Chunk land/NN And/CC so/RB we/PRP)
#   move/VBP
#   (Chunk forward/RB optimistic/JJ)
#   about/IN
#   (Chunk
#     our/PRP$
#     country/NN
#     faithful/NN
#     to/TO
#     its/PRP$
#     cause/NN
#     and/CC
#     confident/NN)
#   of/IN
#   the/DT
#   (Chunk victories/NNS to/TO)
#   come/VB
#   (Chunk May/NNP God/NNP bless/NN America/NNP Applause/NNP))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-90c37418c60b> in <module>()
# ----> 1 chink(letters_only)
#
# <ipython-input-47-97d5a59f60af> in chink(document)
#       3         for i in document:
#       4             words = nltk.word_tokenize(document)
# ----> 5             tagged = nltk.pos_tag(words)
#       6             chunkGram = r"""Chunk: {<.*>+}
#       7                                     }<VB.?|IN|DT>+{"""
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\__init__.py in pos_tag(tokens, tagset, lang)
#     125     """
#     126     tagger = _get_tagger(lang)
# --> 127     return _pos_tag(tokens, tagset, tagger)
#     128
#     129
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\__init__.py in _pos_tag(tokens, tagset, tagger)
#      93
#      94 def _pos_tag(tokens, tagset, tagger):
# ---> 95     tagged_tokens = tagger.tag(tokens)
#      96     if tagset:
#      97         tagged_tokens = [(token, map_tag('en-ptb', tagset, tag)) for (token, tag) in tagged_tokens]
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\perceptron.py in tag(self, tokens)
#     154             tag = self.tagdict.get(word)
#     155             if not tag:
# --> 156                 features = self._get_features(i, word, context, prev, prev2)
#     157                 tag = self.model.predict(features)
#     158             output.append((word, tag))
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\perceptron.py in _get_features(self, i, word, context, prev, prev2)
#     261         add('i tag+i-2 tag', prev, prev2)
#     262         add('i word', context[i])
# --> 263         add('i-1 tag+i word', prev, context[i])
#     264         add('i-1 word', context[i-1])
#     265         add('i-1 suffix', context[i-1][-3:])
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\perceptron.py in add(name, *args)
#     249         '''
#     250         def add(name, *args):
# --> 251             features[' '.join((name,) + tuple(args))] += 1
#     252
#     253         i += len(self.START)
#
# KeyboardInterrupt:

# %% [markdown]
#  ## IMP
#     In part of speech tag we provide a tag to each names but we still end up the problem of not getting a word for eg George W.BUsh together. So we use chunking

# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# One of the most major forms of chunking in natural language processing is called "Named Entity Recognition." The idea is to have the machine immediately be able to pull out "entities" like people, places, things, locations, monetary figures, and more.
#
# This can be a bit of a challenge, but NLTK is this built in for us. There are two major options with NLTK's named entity recognition: either recognize all named entities, or recognize named entities as their respective type, like people, places, locations, etc.

# %%
def NamedEntity(document):
    try:
        for i in document:
            words = nltk.word_tokenize(document)
            tagged = nltk.pos_tag(words)
            namedEnt = nltk.ne_chunk(tagged,binary=True)
            for subtree in namedEnt.subtrees(filter=lambda t: t.label() == 'NE'):
                print(subtree)
            
           
        
    except Exception as e:
        print(str(e))

# %%
NamedEntity(letters_only)
# Out:
# (NE GEORGE/NNP)
# (NE THE/NNP)
# (NE CONGRESS/NNP)
# (NE THE/NNP UNION/NNP)
# (NE nJanuary/JJ)
# (NE Cheney/NNP)
# (NE Congress/NNP)
# (NE Supreme/NNP Court/NNP)
# (NE America/NNP)
# (NE Coretta/NNP Scott/NNP King/NNP Applause/NNP)
# (NE George/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP)
# (NE America/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Applause/NNP Abroad/NNP)
# (NE America/NNP)
# (NE Applause/NNP Far/NNP)
# (NE Afghanistan/NNP)
# (NE Iraqis/NNP)
# (NE Lebanon/NNP)
# (NE Egypt/NNP)
# (NE Syria/NNP)
# (NE Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (NE Iran/NNP)
# (NE Applause/NNP)
# (NE George/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP No/NNP)
# (NE Middle/NNP East/NNP)
# (NE Iraq/NNP)
# (NE America/NNP)
# (NE Beslan/NNP)
# (NE London/NNP)
# (NE United/NNP States/NNPS)
# (NE Applause/NNP America/NNP)
# (NE Europe/NNP)
# (NE George/NNP)
# (NE Congress/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP)
# (NE Afghanistan/NNP)
# (NE National/NNP Assembly/NNP)
# (NE Iraq/NNP)
# (NE Iraqis/NNP)
# (NE Iraqi/NNP)
# (NE Iraqis/NNP)
# (NE Iraqi/JJ)
# (NE Iraqis/NNP)
# (NE Iraq/NNP)
# (NE Iraqi/NNP)
# (NE Iraqi/NNP)
# (NE Iraqi/NNP)
# (NE Washington/NNP)
# (NE Iraq/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Hindsight/NNP)
# (NE Iraq/NNP)
# (NE Iraqi/NNP)
# (NE Laden/NNP)
# (NE Zarqawi/NNP)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE American/JJ)
# (NE Applause/NNP Laura/NNP Bush/NNP)
# (NE Union/NNP Address/NNP)
# (NE United/NNP States/NNPS Capitol/NNP)
# (NE Washington/NNP White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP)
# (NE Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (NE American/NNP)
# (NE Dan/NNP)
# (NE Never/NNP)
# (NE Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (NE Sara/NNP Jo/NNP)
# (NE Welcome/NNP Applause/NNP)
# (NE America/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Middle/NNP East/NNP)
# (NE Egypt/NNP)
# (NE Palestinian/JJ)
# (NE Hamas/NNP)
# (NE Israel/NNP)
# (NE Applause/NNP Saudi/NNP Arabia/NNP)
# (NE Middle/NNP East/NNP)
# (NE Middle/NNP East/NNP)
# (NE Applause/NNP)
# (NE George/NNP)
# (NE House/NNP)
# (NE United/NNP States/NNPS Capitol/NNP White/NNP House/NNP)
# (NE Eric/NNP)
# (NE Iran/NNP)
# (NE Palestinian/JJ)
# (NE Lebanon/NNP)
# (NE Iranian/JJ)
# (NE Iranian/JJ)
# (NE America/NNP)
# (NE Iran/NNP America/NNP)
# (NE Iran/NNP Applause/NNP)
# (NE HIV/NNP)
# (NE AIDS/NNP)
# (NE United/NNP States/NNPS)
# (NE Congress/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Patriot/NNP Act/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE America/NNP If/IN)
# (NE Iraq/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE Roosevelt/NNP)
# (NE Truman/NNP)
# (NE Kennedy/NNP)
# (NE Reagan/NNP)
# (NE America/NNP)
# (NE Congress/NNP And/CC)
# (NE America/NNP)
# (NE America/NNP)
# (NE Japan/NNP)
# (NE European/NNP Union/NNP)
# (NE Applause/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE China/NNP)
# (NE India/NNP)
# (NE Washington/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE American/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP)
# (NE Clinton/NNP Laughter/NNP)
# (NE Social/NNP Security/NNP Medicare/NNP)
# (NE Medicaid/NNP)
# (NE Congress/NNP)
# (NE Social/NNP)
# (NE Applause/NNP)
# (NE Social/NNP Security/NNP Medicare/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE America/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE Applause/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE Applause/NNP And/CC)
# (NE American/JJ)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE America/NNP)
# (NE Advanced/NNP Energy/NNP)
# (NE Energy/NNP)
# (NE Applause/NNP Breakthroughs/NNP)
# (NE Middle/NNP East/NNP)
# (NE Applause/NNP By/IN)
# (NE America/NNP)
# (NE Middle/NNP Eastern/NNP)
# (NE America/NNP)
# (NE American/JJ Competitiveness/NNP Initiative/NNP)
# (NE Applause/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Applause/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Applause/NNP)
# (NE American/JJ Competitiveness/NNP Initiative/NNP)
# (NE American/JJ)
# (NE America/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Republican/NNP)
# (NE Applause/NNP Yet/NNP)
# (NE America/NNP)
# (NE American/JJ)
# (NE Supreme/NNP Court/NNP)
# (NE John/NNP Roberts/NNP)
# (NE Justice/NNP Sam/NNP Alito/NNP)
# (NE Senate/NNP)
# (NE Applause/NNP)
# (NE American/NNP For/IN)
# (NE United/NNP States/NNPS)
# (NE Justice/NNP Sandra/NNP)
# (NE Applause/NNP Honorable/NNP)
# (NE Washington/NNP)
# (NE America/NNP)
# (NE Youth/NNP Initiative/NNP)
# (NE America/NNP)
# (NE New/NNP Orleans/NNP)
# (NE New/NNP Orleans/NNP)
# (NE HIV/NNP)
# (NE HIV/NNP)
# (NE African/JJ)
# (NE Congress/NNP)
# (NE Ryan/NNP White/NNP Act/NNP)
# (NE AIDS/NNP)
# (NE America/NNP Applause/NNP)
# (NE African/JJ)
# (NE American/JJ)
# (NE AIDS/NNP)
# (NE America/NNP Applause/NNP Fellow/NNP)
# (NE Lincoln/NNP)
# (NE Martin/NNP Luther/NNP King/NNP)
# (NE Birmingham/NNP)
# (NE Selma/NNP)
# (NE United/NNP States/NNPS)
# (NE Europe/NNP)
# (NE America/NNP Applause/NNP)
# (NE GEORGE/NNP)
# (NE THE/NNP)
# (NE CONGRESS/NNP)
# (NE THE/NNP UNION/NNP)
# (NE nJanuary/JJ)
# (NE Cheney/NNP)
# (NE Congress/NNP)
# (NE Supreme/NNP Court/NNP)
# (NE America/NNP)
# (NE Coretta/NNP Scott/NNP King/NNP Applause/NNP)
# (NE George/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP)
# (NE America/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Applause/NNP Abroad/NNP)
# (NE America/NNP)
# (NE Applause/NNP Far/NNP)
# (NE Afghanistan/NNP)
# (NE Iraqis/NNP)
# (NE Lebanon/NNP)
# (NE Egypt/NNP)
# (NE Syria/NNP)
# (NE Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (NE Iran/NNP)
# (NE Applause/NNP)
# (NE George/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP No/NNP)
# (NE Middle/NNP East/NNP)
# (NE Iraq/NNP)
# (NE America/NNP)
# (NE Beslan/NNP)
# (NE London/NNP)
# (NE United/NNP States/NNPS)
# (NE Applause/NNP America/NNP)
# (NE Europe/NNP)
# (NE George/NNP)
# (NE Congress/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP)
# (NE Afghanistan/NNP)
# (NE National/NNP Assembly/NNP)
# (NE Iraq/NNP)
# (NE Iraqis/NNP)
# (NE Iraqi/NNP)
# (NE Iraqis/NNP)
# (NE Iraqi/JJ)
# (NE Iraqis/NNP)
# (NE Iraq/NNP)
# (NE Iraqi/NNP)
# (NE Iraqi/NNP)
# (NE Iraqi/NNP)
# (NE Washington/NNP)
# (NE Iraq/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Hindsight/NNP)
# (NE Iraq/NNP)
# (NE Iraqi/NNP)
# (NE Laden/NNP)
# (NE Zarqawi/NNP)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE American/JJ)
# (NE Applause/NNP Laura/NNP Bush/NNP)
# (NE Union/NNP Address/NNP)
# (NE United/NNP States/NNPS Capitol/NNP)
# (NE Washington/NNP White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP)
# (NE Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (NE American/NNP)
# (NE Dan/NNP)
# (NE Never/NNP)
# (NE Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (NE Sara/NNP Jo/NNP)
# (NE Welcome/NNP Applause/NNP)
# (NE America/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Middle/NNP East/NNP)
# (NE Egypt/NNP)
# (NE Palestinian/JJ)
# (NE Hamas/NNP)
# (NE Israel/NNP)
# (NE Applause/NNP Saudi/NNP Arabia/NNP)
# (NE Middle/NNP East/NNP)
# (NE Middle/NNP East/NNP)
# (NE Applause/NNP)
# (NE George/NNP)
# (NE House/NNP)
# (NE United/NNP States/NNPS Capitol/NNP White/NNP House/NNP)
# (NE Eric/NNP)
# (NE Iran/NNP)
# (NE Palestinian/JJ)
# (NE Lebanon/NNP)
# (NE Iranian/JJ)
# (NE Iranian/JJ)
# (NE America/NNP)
# (NE Iran/NNP America/NNP)
# (NE Iran/NNP Applause/NNP)
# (NE HIV/NNP)
# (NE AIDS/NNP)
# (NE United/NNP States/NNPS)
# (NE Congress/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Patriot/NNP Act/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE America/NNP If/IN)
# (NE Iraq/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE Roosevelt/NNP)
# (NE Truman/NNP)
# (NE Kennedy/NNP)
# (NE Reagan/NNP)
# (NE America/NNP)
# (NE Congress/NNP And/CC)
# (NE America/NNP)
# (NE America/NNP)
# (NE Japan/NNP)
# (NE European/NNP Union/NNP)
# (NE Applause/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE China/NNP)
# (NE India/NNP)
# (NE Washington/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE American/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP)
# (NE Clinton/NNP Laughter/NNP)
# (NE Social/NNP Security/NNP Medicare/NNP)
# (NE Medicaid/NNP)
# (NE Congress/NNP)
# (NE Social/NNP)
# (NE Applause/NNP)
# (NE Social/NNP Security/NNP Medicare/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE America/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE Applause/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE Applause/NNP And/CC)
# (NE American/JJ)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE America/NNP)
# (NE Advanced/NNP Energy/NNP)
# (NE Energy/NNP)
# (NE Applause/NNP Breakthroughs/NNP)
# (NE Middle/NNP East/NNP)
# (NE Applause/NNP By/IN)
# (NE America/NNP)
# (NE Middle/NNP Eastern/NNP)
# (NE America/NNP)
# (NE American/JJ Competitiveness/NNP Initiative/NNP)
# (NE Applause/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Applause/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Applause/NNP)
# (NE American/JJ Competitiveness/NNP Initiative/NNP)
# (NE American/JJ)
# (NE America/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Republican/NNP)
# (NE Applause/NNP Yet/NNP)
# (NE America/NNP)
# (NE American/JJ)
# (NE Supreme/NNP Court/NNP)
# (NE John/NNP Roberts/NNP)
# (NE Justice/NNP Sam/NNP Alito/NNP)
# (NE Senate/NNP)
# (NE Applause/NNP)
# (NE American/NNP For/IN)
# (NE United/NNP States/NNPS)
# (NE Justice/NNP Sandra/NNP)
# (NE Applause/NNP Honorable/NNP)
# (NE Washington/NNP)
# (NE America/NNP)
# (NE Youth/NNP Initiative/NNP)
# (NE America/NNP)
# (NE New/NNP Orleans/NNP)
# (NE New/NNP Orleans/NNP)
# (NE HIV/NNP)
# (NE HIV/NNP)
# (NE African/JJ)
# (NE Congress/NNP)
# (NE Ryan/NNP White/NNP Act/NNP)
# (NE AIDS/NNP)
# (NE America/NNP Applause/NNP)
# (NE African/JJ)
# (NE American/JJ)
# (NE AIDS/NNP)
# (NE America/NNP Applause/NNP Fellow/NNP)
# (NE Lincoln/NNP)
# (NE Martin/NNP Luther/NNP King/NNP)
# (NE Birmingham/NNP)
# (NE Selma/NNP)
# (NE United/NNP States/NNPS)
# (NE Europe/NNP)
# (NE America/NNP Applause/NNP)
# (NE GEORGE/NNP)
# (NE THE/NNP)
# (NE CONGRESS/NNP)
# (NE THE/NNP UNION/NNP)
# (NE nJanuary/JJ)
# (NE Cheney/NNP)
# (NE Congress/NNP)
# (NE Supreme/NNP Court/NNP)
# (NE America/NNP)
# (NE Coretta/NNP Scott/NNP King/NNP Applause/NNP)
# (NE George/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP)
# (NE America/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Applause/NNP Abroad/NNP)
# (NE America/NNP)
# (NE Applause/NNP Far/NNP)
# (NE Afghanistan/NNP)
# (NE Iraqis/NNP)
# (NE Lebanon/NNP)
# (NE Egypt/NNP)
# (NE Syria/NNP)
# (NE Burma/NNP Zimbabwe/NNP North/NNP Korea/NNP)
# (NE Iran/NNP)
# (NE Applause/NNP)
# (NE George/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP No/NNP)
# (NE Middle/NNP East/NNP)
# (NE Iraq/NNP)
# (NE America/NNP)
# (NE Beslan/NNP)
# (NE London/NNP)
# (NE United/NNP States/NNPS)
# (NE Applause/NNP America/NNP)
# (NE Europe/NNP)
# (NE George/NNP)
# (NE Congress/NNP)
# (NE Union/NNP Address/NNP)
# (NE Capitol/NNP)
# (NE White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP)
# (NE Afghanistan/NNP)
# (NE National/NNP Assembly/NNP)
# (NE Iraq/NNP)
# (NE Iraqis/NNP)
# (NE Iraqi/NNP)
# (NE Iraqis/NNP)
# (NE Iraqi/JJ)
# (NE Iraqis/NNP)
# (NE Iraq/NNP)
# (NE Iraqi/NNP)
# (NE Iraqi/NNP)
# (NE Iraqi/NNP)
# (NE Washington/NNP)
# (NE Iraq/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Hindsight/NNP)
# (NE Iraq/NNP)
# (NE Iraqi/NNP)
# (NE Laden/NNP)
# (NE Zarqawi/NNP)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE American/JJ)
# (NE Applause/NNP Laura/NNP Bush/NNP)
# (NE Union/NNP Address/NNP)
# (NE United/NNP States/NNPS Capitol/NNP)
# (NE Washington/NNP White/NNP House/NNP)
# (NE Eric/NNP Draper/NNP)
# (NE Marine/NNP Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (NE American/NNP)
# (NE Dan/NNP)
# (NE Never/NNP)
# (NE Staff/NNP Sergeant/NNP Dan/NNP Clay/NNP)
# (NE Sara/NNP Jo/NNP)
# (NE Welcome/NNP Applause/NNP)
# (NE America/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Middle/NNP East/NNP)
# (NE Egypt/NNP)
# (NE Palestinian/JJ)
# (NE Hamas/NNP)
# (NE Israel/NNP)
# (NE Applause/NNP Saudi/NNP Arabia/NNP)
# (NE Middle/NNP East/NNP)
# (NE Middle/NNP East/NNP)
# (NE Applause/NNP)
# (NE George/NNP)
# (NE House/NNP)
# (NE United/NNP States/NNPS Capitol/NNP White/NNP House/NNP)
# (NE Eric/NNP)
# (NE Iran/NNP)
# (NE Palestinian/JJ)
# (NE Lebanon/NNP)
# (NE Iranian/JJ)
# (NE Iranian/JJ)
# (NE America/NNP)
# (NE Iran/NNP America/NNP)
# (NE Iran/NNP Applause/NNP)
# (NE HIV/NNP)
# (NE AIDS/NNP)
# (NE United/NNP States/NNPS)
# (NE Congress/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Patriot/NNP Act/NNP)
# (NE United/NNP States/NNPS)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE America/NNP If/IN)
# (NE Iraq/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE Roosevelt/NNP)
# (NE Truman/NNP)
# (NE Kennedy/NNP)
# (NE Reagan/NNP)
# (NE America/NNP)
# (NE Congress/NNP And/CC)
# (NE America/NNP)
# (NE America/NNP)
# (NE Japan/NNP)
# (NE European/NNP Union/NNP)
# (NE Applause/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE China/NNP)
# (NE India/NNP)
# (NE Washington/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE America/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE American/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP)
# (NE Clinton/NNP Laughter/NNP)
# (NE Social/NNP Security/NNP Medicare/NNP)
# (NE Medicaid/NNP)
# (NE Congress/NNP)
# (NE Social/NNP)
# (NE Applause/NNP)
# (NE Social/NNP Security/NNP Medicare/NNP)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE America/NNP)
# (NE American/JJ)
# (NE American/JJ)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE Applause/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE Applause/NNP And/CC)
# (NE American/JJ)
# (NE Congress/NNP)
# (NE Applause/NNP Keeping/NNP America/NNP)
# (NE America/NNP)
# (NE Advanced/NNP Energy/NNP)
# (NE Energy/NNP)
# (NE Applause/NNP Breakthroughs/NNP)
# (NE Middle/NNP East/NNP)
# (NE Applause/NNP By/IN)
# (NE America/NNP)
# (NE Middle/NNP Eastern/NNP)
# (NE America/NNP)
# (NE American/JJ Competitiveness/NNP Initiative/NNP)
# (NE Applause/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Applause/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Applause/NNP)
# (NE American/JJ Competitiveness/NNP Initiative/NNP)
# (NE American/JJ)
# (NE America/NNP)
# (NE America/NNP)
# (NE America/NNP)
# (NE Republican/NNP)
# (NE Applause/NNP Yet/NNP)
# (NE America/NNP)
# (NE American/JJ)
# (NE Supreme/NNP Court/NNP)
# (NE John/NNP Roberts/NNP)
# (NE Justice/NNP Sam/NNP Alito/NNP)
# (NE Senate/NNP)
# (NE Applause/NNP)
# (NE American/NNP For/IN)
# (NE United/NNP States/NNPS)
# (NE Justice/NNP Sandra/NNP)
# (NE Applause/NNP Honorable/NNP)
# (NE Washington/NNP)
# (NE America/NNP)
# (NE Youth/NNP Initiative/NNP)
# (NE America/NNP)
# (NE New/NNP Orleans/NNP)
# (NE New/NNP Orleans/NNP)
# (NE HIV/NNP)
# (NE HIV/NNP)
# (NE African/JJ)
# (NE Congress/NNP)
# (NE Ryan/NNP White/NNP Act/NNP)
# (NE AIDS/NNP)
# (NE America/NNP Applause/NNP)
# (NE African/JJ)
# (NE American/JJ)
# (NE AIDS/NNP)
# (NE America/NNP Applause/NNP Fellow/NNP)
# (NE Lincoln/NNP)
# (NE Martin/NNP Luther/NNP King/NNP)
# (NE Birmingham/NNP)
# (NE Selma/NNP)
# (NE United/NNP States/NNPS)
# (NE Europe/NNP)
# (NE America/NNP Applause/NNP)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-e94b9d8de916> in <module>()
# ----> 1 NamedEntity(letters_only)
#
# <ipython-input-52-1d179c2bac71> in NamedEntity(document)
#       4             words = nltk.word_tokenize(document)
#       5             tagged = nltk.pos_tag(words)
# ----> 6             namedEnt = nltk.ne_chunk(tagged,binary=True)
#       7             for subtree in namedEnt.subtrees(filter=lambda t: t.label() == 'NE'):
#       8                 print(subtree)
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\chunk\__init__.py in ne_chunk(tagged_tokens, binary)
#     175         chunker_pickle = _MULTICLASS_NE_CHUNKER
#     176     chunker = load(chunker_pickle)
# --> 177     return chunker.parse(tagged_tokens)
#     178
#     179 def ne_chunk_sents(tagged_sentences, binary=False):
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\chunk\named_entity.py in parse(self, tokens)
#     120         Each token should be a pos-tagged word
#     121         """
# --> 122         tagged = self._tagger.tag(tokens)
#     123         tree = self._tagged_to_parse(tagged)
#     124         return tree
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\sequential.py in tag(self, tokens)
#      61         tags = []
#      62         for i in range(len(tokens)):
# ---> 63             tags.append(self.tag_one(tokens, i, tags))
#      64         return list(zip(tokens, tags))
#      65
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\sequential.py in tag_one(self, tokens, index, history)
#      81         tag = None
#      82         for tagger in self._taggers:
# ---> 83             tag = tagger.choose_tag(tokens, index, history)
#      84             if tag is not None:
#      85                 break
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\tag\sequential.py in choose_tag(self, tokens, index, history)
#     636         # higher than that cutoff first; otherwise, return None.
#     637         if self._cutoff_prob is None:
# --> 638             return self._classifier.classify(featureset)
#     639
#     640         pdist = self._classifier.prob_classify(featureset)
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\classify\maxent.py in classify(self, featureset)
#     144
#     145     def classify(self, featureset):
# --> 146         return self.prob_classify(featureset).max()
#     147
#     148     def prob_classify(self, featureset):
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\classify\maxent.py in prob_classify(self, featureset)
#     149         prob_dict = {}
#     150         for label in self._encoding.labels():
# --> 151             feature_vector = self._encoding.encode(featureset, label)
#     152
#     153             if self._logarithmic:
#
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\classify\maxent.py in encode(self, featureset, label)
#     530             # Known feature name & value:
#     531             if (fname, fval, label) in self._mapping:
# --> 532                 encoding.append((self._mapping[fname, fval, label], 1))
#     533
#     534             # Otherwise, we might want to fire an "unseen-value feature".
#
# KeyboardInterrupt:

# %% [raw]
# # Example
# NE Type and Examples
# ORGANIZATION - Georgia-Pacific Corp., WHO
# PERSON - Eddy Bonte, President Obama
# LOCATION - Murray River, Mount Everest
# DATE - June, 2008-06-29
# TIME - two fifty a m, 1:30 p.m.
# MONEY - 175 million Canadian Dollars, GBP 10.40
# PERCENT - twenty pct, 18.75 %
# FACILITY - Washington Monument, Stonehenge
# GPE - South East Asia, Midlothian

# %% [markdown]
# # Lemmatizing

# %% [markdown]
# A very similar operation to stemming is called lemmatizing. The major difference between these is, as you saw earlier, stemming can often create non-existent words, whereas lemmas are actual words.

# %%
from nltk.stem import WordNetLemmatizer

# %%
lem = WordNetLemmatizer()

# %%
print(lem.lemmatize("cat"))
print(lem.lemmatize("cacti"))
print(lem.lemmatize("geeze"))
print(lem.lemmatize("rocks"))
print(lem.lemmatize("pythonli"))
print(lem.lemmatize("better"))
# Out:
# cat
# cactus
# geeze
# rock
# pythonli
# better

# %%
print(lem.lemmatize("better",pos="a"))
print(lem.lemmatize("best",pos="a"))
print(lem.lemmatize("run"))
# Out:
# good
# best
# run

# %% [markdown]
# # Corpara

# %%
print(nltk.__file__)
# Out:
# C:\Users\aswat\Anaconda3\lib\site-packages\nltk\__init__.py

# %% [markdown]
# # WordNet

# %% [markdown]
# WordNet is a lexical database for the English language, which was created by Princeton, and is part of the NLTK corpus.
#
# You can use WordNet alongside the NLTK module to find the meanings of words, synonyms, antonyms, and more. Let's cover some examples.

# %%
from nltk.corpus import wordnet

# %%
syns = wordnet.synsets("program")

# %%
print(syns)
# Out:
# [Synset('plan.n.01'), Synset('program.n.02'), Synset('broadcast.n.02'), Synset('platform.n.02'), Synset('program.n.05'), Synset('course_of_study.n.01'), Synset('program.n.07'), Synset('program.n.08'), Synset('program.v.01'), Synset('program.v.02')]

# %%
print(syns[0].lemmas())
# Out:
# [Lemma('plan.n.01.plan'), Lemma('plan.n.01.program'), Lemma('plan.n.01.programme')]

# %%
print(syns[0].lemmas()[0].name())
# Out:
# plan

# %%
#definition
print(syns[0].definition())
# Out:
# a series of steps to be carried out or goals to be accomplished

# %%
#examples
print(syns[0].examples())
# Out:
# ['they drew up a six-step plan', 'they discussed plans for a new bond issue']

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(set(synonyms))
print(set(antonyms))
# Out:
# {'unspoiled', 'serious', 'practiced', 'right', 'estimable', 'undecomposed', 'adept', 'ripe', 'thoroughly', 'near', 'well', 'expert', 'honorable', 'sound', 'safe', 'secure', 'skilful', 'honest', 'good', 'salutary', 'proficient', 'commodity', 'trade_good', 'skillful', 'full', 'dependable', 'beneficial', 'effective', 'soundly', 'in_force', 'upright', 'respectable', 'dear', 'unspoilt', 'goodness', 'just', 'in_effect'}
# {'evil', 'bad', 'ill', 'badness', 'evilness'}

# %%
#SIMILARITY

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091

# %% [markdown]
# Next, we can also easily use WordNet to compare the similarity of two words and their tenses, by incorporating the Wu and Palmer method for semantic related-ness
