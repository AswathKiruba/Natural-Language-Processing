# %% [markdown]
# # Twitter Sentiment Analysis

# %%
# registered account under the name of DataStrange

#imports
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
from textblob import TextBlob

# %%
#consumer key, consumer secret, access token, access secret.
ckey="NzgaSJAv2pxYtzmeOZ83hERwo"
csecret="zOgysOYxqpcmJyCZasym8YWBAP1BHDc74fkkDAbS9HE05EZRlo"
atoken="920796118434361344-t1MbCgUF6EDpnZoMihKduFsqfOLRgBo"
asecret="nG2H0oJNl4oefLs9GbpjyAcoLPvTuidrDusVFYtKWPEYM"

class listener(StreamListener):

    def on_data(self, data):
        print(data)
        return(True)

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

# %%
#Text Blob is great package to do twitter sentiment analysis
ash=TextBlob("Aswath is angry that he is never able to his Bubbly")

# %%
#tags
ash.tags
# Out:
# [('Aswath', 'NNP'),
#  ('is', 'VBZ'),
#  ('angry', 'JJ'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('is', 'VBZ'),
#  ('never', 'RB'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('his', 'PRP$'),
#  ('Bubbly', 'NNP')]

# %%
# words
ash.words
# Out:
# WordList(['Aswath', 'is', 'angry', 'that', 'he', 'is', 'never', 'able', 'to', 'his', 'Bubbly'])

# %%
#Sentiment
ash.sentiment.polarity
# Out:
# -0.375

# %%
api = tweepy.API(auth)

# %%
public_tweets = api.search('Shootout')

for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# RT @DarisCowieson: @kinger_8 shootout goal, down goes BC! #U16TeamMB #WHLCup #mybrotheriscoolerthanyours https://t.co/q17SFNGPqs
# Sentiment(polarity=-0.19444444444444448, subjectivity=0.2888888888888889)
# I added a video to a @YouTube playlist https://t.co/Xdm8mzUGKR $10k Coyote vs LS3 Shootout - The Build
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @WDTsports: HS boys soccer: Section 3 Class B first round, IHC def. Central Valley Academy in a shootout 3-0. IHC will travel to play Ca…
# Sentiment(polarity=0.016666666666666663, subjectivity=0.3277777777777778)
# I added a video to a @YouTube playlist https://t.co/TSPhPi7z1F Power Bank Shootout Ravpower vs Anker (Long full test version)
# Sentiment(polarity=0.15, subjectivity=0.47500000000000003)
# Ice Hawks win in double overtime shootout 4-3 over Riverland. Women… https://t.co/lGjwctOkoF
# Sentiment(polarity=0.4, subjectivity=0.2)
# ...

# %%
# Cont use blog for 
#twitterStream = Stream(auth, listener())
#tweet = twitterStream.filter(track=["vegas"])
#analysis = TextBlob(tweet)
#print(analysis.sentiment)
# Out:
# {"created_at":"Thu Oct 19 02:10:31 +0000 2017","id":920834515169243136,"id_str":"920834515169243136","text":"RT @Thomas1774Paine: Hahahahahahaha This Story predicted Ellen would give Campos a new Ford or NFL tix. Turns out she gave him NFL tix.\u2026 ","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":3649036098,"id_str":"3649036098","name":"NextLevelKnowledge","screen_name":"NextLevelknow","location":"Sacramento, CA","url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":212,"friends_count":197,"listed_count":20,"favourites_count":264,"statuses_count":30991,"created_at":"Tue Sep 22 13:36:55 +0000 2015","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contribut
# ...

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import sentiment_mod as s



class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)

        if confidence*100 >= 80:
            output = open("twitter-out.txt","a")
            output.write(sentiment_value)
            output.write('\n')
            output.close()

        return True

    def on_error(self, status):
        print(status)

# %%
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["vegas"])
# Out:
# RT @ShutUpShow: ICYMI, we talked about the best games we played at #SHUX2017, including expansions for Inis and Lords of Vegas! https://t.c… pos 1.0
# Refrigerant News! Service World Expo Draws a Full House in Las Vegas https://t.co/2Tpyrflgtz neg 0.8
# RT @LiveNation: Enter for a chance to meet @JLo in Las Vegas, plus free blowouts from Drybar. Go to @thedrybar's Instagram to enter…  neg 1.0
# The hotel in Vegas owns the Helen show.  They are playing it safe cause they have more control on this talk show! (… https://t.co/biEPo1u2mf pos 0.6
# RT @worldcoresocial: Chinese visitors to New York and Las Vegas may pay for taxi using Alipay https://t.co/3aRvyTLOwX #Mobilecommerce…  pos 1.0
# RT @madelainepetsch: Is Vegas anyone else's favorite character?? #Riverdale neg 1.0
# AP: Country stars honor victims of mass shooting in Las Vegas at CMT Artists of Year show. … https://t.co/gwXr2jHztZ neg 1.0
# Why...what happens in Vegas neg 0.8
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import time
# %matplotlib inline

style.use("ggplot")

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate(i):
    pullData = open("twitter-out.txt","r").read()
    lines = pullData.split('\n')

    xar = []
    yar = []

    x = 0
    y = 0

    for l in lines[-200:]:
        x += 1
        if "pos" in l:
            y += 1
        elif "neg" in l:
            y -= 1

        xar.append(x)
        yar.append(y)
        
    ax1.clear()
    ax1.plot(xar,yar)
ani = animation.FuncAnimation(fig, animate, interval=1000)


plt.show()
